# %% [markdown]
# ### 1. Setting

# %%
# Seed
from numpy.random import seed
seed(1234)
from tensorflow import set_random_seed
set_random_seed(1234)

# %%
# Warning Message
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### 2. Data Loading

# %%
# Original 데이터
import pandas as pd
data_original_2017 = pd.read_excel('./data/2017년 주가 기본 데이터.xlsx')
data_original_2018 = pd.read_excel('./data/2017년 주가 기본 데이터.xlsx')
data_original_2019 = pd.read_excel('./data/2017년 주가 기본 데이터.xlsx')

# %%
# 사내 창출 데이터
import pandas as pd
data_new_2017 = pd.read_excel('./data/2017년 주가 관련 사내 창출 데이터.xlsx')
data_new_2018 = pd.read_excel('./data/2017년 주가 관련 사내 창출 데이터.xlsx')
data_new_2019 = pd.read_excel('./data/2017년 주가 관련 사내 창출 데이터.xlsx')

# %%
# Unnamed 칼럼 제거
data_original_2017 = data_original_2017[data_original_2017.columns[1:]]
data_new_2017 = data_new_2017[data_new_2017.columns[1:]]

# %% [markdown]
# ### 3. Data Head

# %%
data_original_2017
# Out:
#              date   open   high    low  close  trading_volume  trading_value  \
# 0      2017-01-02  79905  81585  79170  79800            2730      208226200
# 1      2017-01-03  80535  80535  79170  79800            3093      235375100
# 2      2017-01-04  80535  80955  76965  77175            2183      162518300
# 3      2017-01-05  77070  78855  75600  78225            2560      188149700
# 4      2017-01-06  78225  79800  77280  77385            2386      178225000
# ...           ...    ...    ...    ...    ...             ...            ...
# 587160 2017-12-21  11550  11950  10500  10600         1305109    14479217150
# 587161 2017-12-22  10300  11250   9650   9960         1040672    10741679320
# 587162 2017-12-26  10150  10350   9410   9410          481185     4688868880
# 587163 2017-12-27   9540  11650   9470   9750         5397011    57844627480
# 587164 2017-12-28   9880  10600   9780  10050          912331     9164235980
#
#           code
# 0       012320
# 1       012320
# 2       012320
# 3       012320
# 4       012320
# ...        ...
# 587160  187870
# 587161  187870
# 587162  187870
# 587163  187870
# 587164  187870
#
# [587165 rows x 8 columns]

# %%
data_new_2017
# Out:
#              date    kindex     index     score  probability    code
# 0      2017-01-02  0.000685  0.388889  0.546392     6.863271  012320
# 1      2017-01-03  0.000685  0.388889  0.546392     6.863271  012320
# 2      2017-01-04  0.001262  0.555556  0.974026     3.584906  012320
# 3      2017-01-05  0.001213  0.625000  0.948718     8.089888  012320
# 4      2017-01-06  0.001226  0.625000  0.948718     8.089888  012320
# ...           ...       ...       ...       ...          ...     ...
# 587160 2017-12-21  0.009434  1.000000  1.000000    30.000000  187870
# 587161 2017-12-22  0.010040  1.000000  1.000000    30.000000  187870
# 587162 2017-12-26  0.010627  1.000000  1.000000    30.000000  187870
# 587163 2017-12-27  0.010256  1.000000  1.000000    30.000000  187870
# 587164 2017-12-28  0.009950  1.000000  1.000000    30.000000  187870
#
# [587165 rows x 6 columns]

# %% [markdown]
# ### 4. Code

# %%
CODE_LIST = data_new_2019.code.value_counts().index

# %% [markdown]
# ### 5. Data Merge & Labeling

# %%
stock_data = pd.DataFrame()
df_final = pd.DataFrame()
NUM = 0

for code in CODE_LIST :
    
    # 2017
    data_original = data_original_2017[data_original_2017['code'] == code]
    data_new = data_new_2017[data_new_2017['code'] == code]
    data = pd.merge(data_original, data_new, how='left')
    data = data[['date','trading_volume', 'trading_value', 'kindex', 'index', 'score', 'probability', 'close']]
    df_final = df_final.append(data)
    
    # 2018
    data_original = data_original_2018[data_original_2018['code'] == code]
    data_new = data_new_2018[data_new_2018['code'] == code]
    data = pd.merge(data_original, data_new, how='left')
    data = data[['date','trading_volume', 'trading_value', 'kindex', 'index', 'score', 'probability', 'close']]
    df_final = df_final.append(data)
    
    # 2019
    data_original = data_original_2019[data_original_2019['code'] == code]
    data_new = data_new_2019[data_new_2019['code'] == code]
    data = pd.merge(data_original, data_new, how='left')
    data = data[['date','trading_volume', 'trading_value', 'kindex', 'index', 'score', 'probability', 'close']]
    df_final = df_final.append(data)
    
    # Index Reset
    df_final = df_final.reset_index()
    
    # Data Shfit 생성    
    df_final['close5'] = df_final['close'].shift(-5)
    df_final['pred_rate'] = (100 * (df_final['close5'] - df_final['close'])) / df_final['close']
    df_final = df_final[:-5]

    # 예측값 라벨링
    def labeling(x) : 
        if x > 10.00 : 
            result = '10.00 ~ Inf'
        elif x > 5.00 : 
            result = '5.00 ~ 9.99'
        elif x > 1.00 : 
            result = '1.00 ~ 4.99'
        elif x > -1.00 : 
            result = '-1.00 ~ 1.00'
        elif x > -5.00 : 
            result = '-5.00 ~ -1.01'
        elif x > -10.00 : 
            result = '-10.00 ~ -5.01'
        else : 
            result = '-Inf ~ -10.00'
        return result

    # 함수 적용
    df_final['pred_rate_label'] = df_final['pred_rate'].apply(lambda x : labeling(x))
    
    # Feature Selecting
    df_final = df_final[['trading_volume', 'trading_value', 'kindex', 'index', 'score', 'probability', 'pred_rate_label']]

    # MinMaxScaling
    from sklearn.preprocessing import MinMaxScaler
    scaler = MinMaxScaler()
    scaler.fit(df_final[['trading_volume', 'trading_value', 'kindex', 'index', 'score', 'probability']])
    X = scaler.transform(df_final[['trading_volume', 'trading_value', 'kindex', 'index', 'score', 'probability']])
    y = df_final[['pred_rate_label']]
    df_final_X = pd.DataFrame(X, columns=['trading_volume', 'trading_value', 'kindex', 'index', 'score', 'probability'])
    df_final_y = pd.DataFrame(y, columns=['pred_rate_label'])
    df_final = pd.concat([df_final_X, df_final_y], axis=1)
    
    # 최종 데이터셋에 추가
    stock_data = stock_data.append(df_final)
    
    # df_final Reset
    df_final = pd.DataFrame()
    
    # 경과 check
    if NUM % 100 == 0 : 
        print("{:4}번째 종목 계산 중...." .format(NUM))
    NUM += 1
# Out:
#    0번째 종목 계산 중....
#  100번째 종목 계산 중....
#  200번째 종목 계산 중....
#  300번째 종목 계산 중....
#  400번째 종목 계산 중....
#  500번째 종목 계산 중....
#  600번째 종목 계산 중....
#  700번째 종목 계산 중....
#  800번째 종목 계산 중....
#  900번째 종목 계산 중....
# 1000번째 종목 계산 중....
# 1100번째 종목 계산 중....
# 1200번째 종목 계산 중....
# 1300번째 종목 계산 중....
# 1400번째 종목 계산 중....
# 1500번째 종목 계산 중....
# 1600번째 종목 계산 중....
# 1700번째 종목 계산 중....
# 1800번째 종목 계산 중....
# 1900번째 종목 계산 중....
# 2000번째 종목 계산 중....
# 2100번째 종목 계산 중....
# 2200번째 종목 계산 중....
# 2300번째 종목 계산 중....
# 2400번째 종목 계산 중....
# 2500번째 종목 계산 중....

# %%
stock_data
# Out:
#     trading_volume  trading_value        kindex     index         score  \
# 0         0.086215       0.096147  2.641792e-05  0.035608  3.048529e-05
# 1         0.320222       0.349699  2.155739e-09  0.000540  2.647771e-09
# 2         0.316485       0.356655  2.155739e-09  0.000540  2.647771e-09
# 3         0.211185       0.238072  2.536944e-09  0.001319  3.023584e-09
# 4         0.164333       0.183067  2.616855e-09  0.001319  3.023584e-09
# ..             ...            ...           ...       ...           ...
# 6         0.000000       0.001407  1.413259e-01  0.000000  0.000000e+00
# 0         1.000000       1.000000  0.000000e+00  0.000000  0.000000e+00
# 1         0.000000       0.000000  8.272858e-01  1.000000  1.000000e+00
# 2         0.229922       0.293471  1.000000e+00  1.000000  1.000000e+00
# 3         1.000000       1.000000  0.000000e+00  0.000000  0.000000e+00
#
#     probability pred_rate_label
# 0      0.375694    -1.00 ~ 1.00
# 1      0.260727  -10.00 ~ -5.01
# 2      0.260727  -10.00 ~ -5.01
# 3      0.265735   -5.00 ~ -1.01
# 4      0.265735     1.00 ~ 4.99
# ..          ...             ...
# 6      0.000000    -1.00 ~ 1.00
# 0      0.000000     5.00 ~ 9.99
# 1      1.000000   -Inf ~ -10.00
# 2      1.000000     10.00 ~ Inf
# 3      0.000000     5.00 ~ 9.99
#
# [1748800 rows x 7 columns]

# %%
stock_data.describe()
# Out:
#        trading_volume  trading_value        kindex         index  \
# count    1.748800e+06   1.748800e+06  1.748800e+06  1.748800e+06
# mean     7.653584e-02   7.420223e-02  2.302800e-01  1.950022e-01
# std      1.306686e-01   1.299528e-01  3.329755e-01  2.760592e-01
# min      0.000000e+00   0.000000e+00  0.000000e+00  0.000000e+00
# 25%      7.687343e-03   6.399293e-03  2.980003e-04  1.733413e-02
# 50%      2.839173e-02   2.586774e-02  1.606672e-03  5.898398e-02
# 75%      8.748234e-02   8.395550e-02  5.137965e-01  2.533333e-01
# max      1.000000e+00   1.000000e+00  1.000000e+00  1.000000e+00
#
#               score   probability
# count  1.748800e+06  1.748800e+06
# mean   2.171584e-01  6.399770e-01
# std    3.296864e-01  3.687509e-01
# min    0.000000e+00  0.000000e+00
# 25%    2.376325e-04  2.847671e-01
# 50%    1.405551e-03  8.755170e-01
# 75%    4.665634e-01  9.850044e-01
# max    1.000000e+00  1.000000e+00

# %%
label_count = pd.DataFrame([stock_data.pred_rate_label.value_counts()]).T
label_count['label'] = label_count.index
plt.figure(figsize=(18,6))
import seaborn as sns
sns.set(style = 'whitegrid')
ax = sns.barplot(x='label', y='pred_rate_label', data=label_count)

# %%
# Label Setting
def label_to_numeric(x) : 
    if x == '-Inf ~ -10.00' : 
        result = 0
    elif x == '-10.00 ~ -5.01' : 
        result = 1
    elif x == '-5.00 ~ -1.01' : 
        result = 2
    elif x == '-1.00 ~ 1.00' : 
        result = 3
    elif x == '1.00 ~ 4.99' : 
        result = 4
    elif x == '5.00 ~ 9.99' : 
        result = 5
    else : 
        result = 6
    return result
        
# 함수 적용
stock_data['label'] = stock_data['pred_rate_label'].apply(lambda x : label_to_numeric(x))
stock_data
# Out:
#     trading_volume  trading_value        kindex     index         score  \
# 0         0.086215       0.096147  2.641792e-05  0.035608  3.048529e-05
# 1         0.320222       0.349699  2.155739e-09  0.000540  2.647771e-09
# 2         0.316485       0.356655  2.155739e-09  0.000540  2.647771e-09
# 3         0.211185       0.238072  2.536944e-09  0.001319  3.023584e-09
# 4         0.164333       0.183067  2.616855e-09  0.001319  3.023584e-09
# ..             ...            ...           ...       ...           ...
# 6         0.000000       0.001407  1.413259e-01  0.000000  0.000000e+00
# 0         1.000000       1.000000  0.000000e+00  0.000000  0.000000e+00
# 1         0.000000       0.000000  8.272858e-01  1.000000  1.000000e+00
# 2         0.229922       0.293471  1.000000e+00  1.000000  1.000000e+00
# 3         1.000000       1.000000  0.000000e+00  0.000000  0.000000e+00
#
#     probability pred_rate_label  label
# 0      0.375694    -1.00 ~ 1.00      3
# 1      0.260727  -10.00 ~ -5.01      1
# 2      0.260727  -10.00 ~ -5.01      1
# 3      0.265735   -5.00 ~ -1.01      2
# 4      0.265735     1.00 ~ 4.99      4
# ..          ...             ...    ...
# 6      0.000000    -1.00 ~ 1.00      3
# 0      0.000000     5.00 ~ 9.99      5
# 1      1.000000   -Inf ~ -10.00      0
# 2      1.000000     10.00 ~ Inf      6
# 3      0.000000     5.00 ~ 9.99      5
#
# [1748800 rows x 8 columns]

# %% [markdown]
# ### LightGBM

# %%
# Train Test Split
from sklearn.model_selection import train_test_split
X = stock_data[['trading_volume', 'trading_value', 'kindex', 'index', 'score', 'probability']].values
y = stock_data[['label']].values
y = y.reshape(-1)
x_train, x_test, y_train, y_test = train_test_split(X, y,test_size=0.1, random_state=1234)
x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train ,test_size=0.2, random_state=1234)

# HyperParameter
params = {
    'task' : 'train',
    'boosting_type' : 'gbdt',
    'objective' : 'multiclass',
    'metric' : {'multi_logloss'},
    'num_leaves' : 63,
    'learning_rate' : 0.1,
    'feature_fraction' : 0.9,
    'bagging_fraction' : 0.9,
    'bagging_freq': 0,
    'verbose' : 1,
    'num_class' : 7,
    'save_binary' : True
}

# Model Fitting
import lightgbm as lgb
lgb_train = lgb.Dataset(x_train, y_train)
lgb_eval = lgb.Dataset(x_test, y_test, reference=lgb_train)
gbm = lgb.train(params,
                lgb_train,
                num_boost_round=500,
                valid_sets=lgb_eval,
                early_stopping_rounds = 100)
# Out:
# [1]	valid_0's multi_logloss: 1.66157
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's multi_logloss: 1.65434
# [3]	valid_0's multi_logloss: 1.64759
# [4]	valid_0's multi_logloss: 1.64176
# [5]	valid_0's multi_logloss: 1.63627
# [6]	valid_0's multi_logloss: 1.63141
# [7]	valid_0's multi_logloss: 1.62682
# [8]	valid_0's multi_logloss: 1.62294
# [9]	valid_0's multi_logloss: 1.61923
# [10]	valid_0's multi_logloss: 1.61568
# [11]	valid_0's multi_logloss: 1.61267
# [12]	valid_0's multi_logloss: 1.61004
# [13]	valid_0's multi_logloss: 1.60734
# [14]	valid_0's multi_logloss: 1.60496
# [15]	valid_0's multi_logloss: 1.60291
# [16]	valid_0's multi_logloss: 1.60093
# [17]	valid_0's multi_logloss: 1.59918
# [18]	valid_0's multi_logloss: 1.59738
# [19]	valid_0's multi_logloss: 1.59571
# [20]	valid_0's multi_logloss: 1.59413
# [21]	valid_0's multi_logloss: 1.59277
# [22]	valid_0's multi_logloss: 1.5912
# [23]	valid_0's multi_logloss: 1.58977
# [24]	valid_0's multi_logloss: 1.58852
# [25]	valid_0's multi_logloss: 1.58736
# [26]	valid_0's multi_logloss: 1.58637
# [27]	valid_0's multi_logloss: 1.58532
# [28]	valid_0's multi_logloss: 1.58423
# [29]	valid_0's multi_logloss: 1.58325
# [30]	valid_0's multi_logloss: 1.58227
# [31]	valid_0's multi_logloss: 1.58141
# [32]	valid_0's multi_logloss: 1.58062
# [33]	valid_0's multi_logloss: 1.5798
# [34]	valid_0's multi_logloss: 1.57906
# [35]	valid_0's multi_logloss: 1.57823
# [36]	valid_0's multi_logloss: 1.57757
# [37]	valid_0's multi_logloss: 1.57679
# [38]	valid_0's multi_logloss: 1.57614
# [39]	valid_0's multi_logloss: 1.5755
# [40]	valid_0's multi_logloss: 1.57479
# [41]	valid_0's multi_logloss: 1.5741
# [42]	valid_0's multi_logloss: 1.57351
# [43]	valid_0's multi_logloss: 1.57294
# [44]	valid_0's multi_logloss: 1.57236
# [45]	valid_0's multi_logloss: 1.57167
# [46]	valid_0's multi_logloss: 1.57113
# [47]	valid_0's multi_logloss: 1.57055
# [48]	valid_0's multi_logloss: 1.56998
# [49]	valid_0's multi_logloss: 1.56946
# [50]	valid_0's multi_logloss: 1.56901
# [51]	valid_0's multi_logloss: 1.56848
# [52]	valid_0's multi_logloss: 1.56794
# [53]	valid_0's multi_logloss: 1.56747
# [54]	valid_0's multi_logloss: 1.567
# [55]	valid_0's multi_logloss: 1.56655
# [56]	valid_0's multi_logloss: 1.56603
# [57]	valid_0's multi_logloss: 1.56562
# [58]	valid_0's multi_logloss: 1.56519
# [59]	valid_0's multi_logloss: 1.56481
# [60]	valid_0's multi_logloss: 1.56432
# [61]	valid_0's multi_logloss: 1.56392
# [62]	valid_0's multi_logloss: 1.56352
# [63]	valid_0's multi_logloss: 1.56314
# [64]	valid_0's multi_logloss: 1.56269
# [65]	valid_0's multi_logloss: 1.56235
# [66]	valid_0's multi_logloss: 1.56196
# [67]	valid_0's multi_logloss: 1.5616
# [68]	valid_0's multi_logloss: 1.56127
# [69]	valid_0's multi_logloss: 1.56089
# [70]	valid_0's multi_logloss: 1.56055
# [71]	valid_0's multi_logloss: 1.56024
# [72]	valid_0's multi_logloss: 1.55987
# [73]	valid_0's multi_logloss: 1.5595
# [74]	valid_0's multi_logloss: 1.55911
# [75]	valid_0's multi_logloss: 1.5588
# [76]	valid_0's multi_logloss: 1.55848
# [77]	valid_0's multi_logloss: 1.55815
# [78]	valid_0's multi_logloss: 1.55777
# [79]	valid_0's multi_logloss: 1.55744
# [80]	valid_0's multi_logloss: 1.55712
# [81]	valid_0's multi_logloss: 1.55681
# [82]	valid_0's multi_logloss: 1.55647
# [83]	valid_0's multi_logloss: 1.55619
# [84]	valid_0's multi_logloss: 1.55587
# [85]	valid_0's multi_logloss: 1.55558
# [86]	valid_0's multi_logloss: 1.55525
# [87]	valid_0's multi_logloss: 1.55497
# [88]	valid_0's multi_logloss: 1.55465
# [89]	valid_0's multi_logloss: 1.55435
# [90]	valid_0's multi_logloss: 1.55405
# [91]	valid_0's multi_logloss: 1.55371
# [92]	valid_0's multi_logloss: 1.55347
# [93]	valid_0's multi_logloss: 1.55326
# [94]	valid_0's multi_logloss: 1.55295
# [95]	valid_0's multi_logloss: 1.55267
# [96]	valid_0's multi_logloss: 1.55239
# [97]	valid_0's multi_logloss: 1.55214
# [98]	valid_0's multi_logloss: 1.55183
# [99]	valid_0's multi_logloss: 1.55154
# [100]	valid_0's multi_logloss: 1.55125
# [101]	valid_0's multi_logloss: 1.55103
# [102]	valid_0's multi_logloss: 1.55077
# [103]	valid_0's multi_logloss: 1.55045
# [104]	valid_0's multi_logloss: 1.55016
# [105]	valid_0's multi_logloss: 1.54993
# [106]	valid_0's multi_logloss: 1.54967
# [107]	valid_0's multi_logloss: 1.54943
# [108]	valid_0's multi_logloss: 1.54916
# [109]	valid_0's multi_logloss: 1.54886
# [110]	valid_0's multi_logloss: 1.54858
# [111]	valid_0's multi_logloss: 1.54833
# [112]	valid_0's multi_logloss: 1.54808
# [113]	valid_0's multi_logloss: 1.54782
# [114]	valid_0's multi_logloss: 1.54761
# [115]	valid_0's multi_logloss: 1.54737
# [116]	valid_0's multi_logloss: 1.54699
# [117]	valid_0's multi_logloss: 1.54673
# [118]	valid_0's multi_logloss: 1.54651
# [119]	valid_0's multi_logloss: 1.54625
# [120]	valid_0's multi_logloss: 1.54596
# [121]	valid_0's multi_logloss: 1.54565
# [122]	valid_0's multi_logloss: 1.5454
# [123]	valid_0's multi_logloss: 1.54519
# [124]	valid_0's multi_logloss: 1.54498
# [125]	valid_0's multi_logloss: 1.54472
# [126]	valid_0's multi_logloss: 1.54453
# [127]	valid_0's multi_logloss: 1.5443
# [128]	valid_0's multi_logloss: 1.54407
# [129]	valid_0's multi_logloss: 1.54385
# [130]	valid_0's multi_logloss: 1.5436
# [131]	valid_0's multi_logloss: 1.54333
# [132]	valid_0's multi_logloss: 1.54308
# [133]	valid_0's multi_logloss: 1.54284
# [134]	valid_0's multi_logloss: 1.54265
# [135]	valid_0's multi_logloss: 1.54239
# [136]	valid_0's multi_logloss: 1.54217
# [137]	valid_0's multi_logloss: 1.54196
# [138]	valid_0's multi_logloss: 1.54168
# [139]	valid_0's multi_logloss: 1.54141
# [140]	valid_0's multi_logloss: 1.54122
# [141]	valid_0's multi_logloss: 1.54099
# [142]	valid_0's multi_logloss: 1.54076
# [143]	valid_0's multi_logloss: 1.54051
# [144]	valid_0's multi_logloss: 1.54025
# [145]	valid_0's multi_logloss: 1.54003
# [146]	valid_0's multi_logloss: 1.53981
# [147]	valid_0's multi_logloss: 1.5396
# [148]	valid_0's multi_logloss: 1.5393
# [149]	valid_0's multi_logloss: 1.53903
# [150]	valid_0's multi_logloss: 1.53883
# [151]	valid_0's multi_logloss: 1.53861
# [152]	valid_0's multi_logloss: 1.53835
# [153]	valid_0's multi_logloss: 1.5381
# [154]	valid_0's multi_logloss: 1.53784
# [155]	valid_0's multi_logloss: 1.53759
# [156]	valid_0's multi_logloss: 1.53731
# [157]	valid_0's multi_logloss: 1.53708
# [158]	valid_0's multi_logloss: 1.53685
# [159]	valid_0's multi_logloss: 1.53662
# [160]	valid_0's multi_logloss: 1.53637
# [161]	valid_0's multi_logloss: 1.53614
# [162]	valid_0's multi_logloss: 1.53597
# [163]	valid_0's multi_logloss: 1.53574
# [164]	valid_0's multi_logloss: 1.53553
# [165]	valid_0's multi_logloss: 1.53531
# [166]	valid_0's multi_logloss: 1.53506
# [167]	valid_0's multi_logloss: 1.53483
# [168]	valid_0's multi_logloss: 1.53458
# [169]	valid_0's multi_logloss: 1.53441
# [170]	valid_0's multi_logloss: 1.53411
# [171]	valid_0's multi_logloss: 1.53388
# [172]	valid_0's multi_logloss: 1.53363
# [173]	valid_0's multi_logloss: 1.53341
# [174]	valid_0's multi_logloss: 1.53316
# [175]	valid_0's multi_logloss: 1.53297
# [176]	valid_0's multi_logloss: 1.53273
# [177]	valid_0's multi_logloss: 1.53253
# [178]	valid_0's multi_logloss: 1.5323
# [179]	valid_0's multi_logloss: 1.53212
# [180]	valid_0's multi_logloss: 1.53194
# [181]	valid_0's multi_logloss: 1.53173
# [182]	valid_0's multi_logloss: 1.53146
# [183]	valid_0's multi_logloss: 1.53126
# [184]	valid_0's multi_logloss: 1.53103
# [185]	valid_0's multi_logloss: 1.53085
# [186]	valid_0's multi_logloss: 1.53061
# [187]	valid_0's multi_logloss: 1.5304
# [188]	valid_0's multi_logloss: 1.53019
# [189]	valid_0's multi_logloss: 1.53
# [190]	valid_0's multi_logloss: 1.52972
# [191]	valid_0's multi_logloss: 1.52953
# [192]	valid_0's multi_logloss: 1.52931
# [193]	valid_0's multi_logloss: 1.52908
# [194]	valid_0's multi_logloss: 1.52885
# [195]	valid_0's multi_logloss: 1.52864
# [196]	valid_0's multi_logloss: 1.52841
# [197]	valid_0's multi_logloss: 1.52817
# [198]	valid_0's multi_logloss: 1.52796
# [199]	valid_0's multi_logloss: 1.52779
# [200]	valid_0's multi_logloss: 1.52756
# [201]	valid_0's multi_logloss: 1.52739
# [202]	valid_0's multi_logloss: 1.52717
# [203]	valid_0's multi_logloss: 1.52697
# [204]	valid_0's multi_logloss: 1.52677
# [205]	valid_0's multi_logloss: 1.52655
# [206]	valid_0's multi_logloss: 1.52635
# [207]	valid_0's multi_logloss: 1.52607
# [208]	valid_0's multi_logloss: 1.52585
# [209]	valid_0's multi_logloss: 1.52564
# [210]	valid_0's multi_logloss: 1.5255
# [211]	valid_0's multi_logloss: 1.52533
# [212]	valid_0's multi_logloss: 1.52511
# [213]	valid_0's multi_logloss: 1.52491
# [214]	valid_0's multi_logloss: 1.5247
# [215]	valid_0's multi_logloss: 1.52452
# [216]	valid_0's multi_logloss: 1.52431
# [217]	valid_0's multi_logloss: 1.52413
# [218]	valid_0's multi_logloss: 1.52388
# [219]	valid_0's multi_logloss: 1.52372
# [220]	valid_0's multi_logloss: 1.52353
# [221]	valid_0's multi_logloss: 1.52335
# [222]	valid_0's multi_logloss: 1.52312
# [223]	valid_0's multi_logloss: 1.52293
# [224]	valid_0's multi_logloss: 1.52276
# [225]	valid_0's multi_logloss: 1.52254
# [226]	valid_0's multi_logloss: 1.52232
# [227]	valid_0's multi_logloss: 1.52211
# [228]	valid_0's multi_logloss: 1.5219
# [229]	valid_0's multi_logloss: 1.52169
# [230]	valid_0's multi_logloss: 1.52153
# [231]	valid_0's multi_logloss: 1.52135
# [232]	valid_0's multi_logloss: 1.52118
# [233]	valid_0's multi_logloss: 1.52103
# [234]	valid_0's multi_logloss: 1.52083
# [235]	valid_0's multi_logloss: 1.52054
# [236]	valid_0's multi_logloss: 1.52031
# [237]	valid_0's multi_logloss: 1.52012
# [238]	valid_0's multi_logloss: 1.51995
# [239]	valid_0's multi_logloss: 1.51979
# [240]	valid_0's multi_logloss: 1.51958
# [241]	valid_0's multi_logloss: 1.51937
# [242]	valid_0's multi_logloss: 1.51919
# [243]	valid_0's multi_logloss: 1.51899
# [244]	valid_0's multi_logloss: 1.5188
# [245]	valid_0's multi_logloss: 1.51862
# [246]	valid_0's multi_logloss: 1.51838
# [247]	valid_0's multi_logloss: 1.51819
# [248]	valid_0's multi_logloss: 1.51799
# [249]	valid_0's multi_logloss: 1.51781
# [250]	valid_0's multi_logloss: 1.51764
# [251]	valid_0's multi_logloss: 1.51747
# [252]	valid_0's multi_logloss: 1.51733
# [253]	valid_0's multi_logloss: 1.51718
# [254]	valid_0's multi_logloss: 1.51699
# [255]	valid_0's multi_logloss: 1.51679
# [256]	valid_0's multi_logloss: 1.5166
# [257]	valid_0's multi_logloss: 1.51635
# [258]	valid_0's multi_logloss: 1.51616
# [259]	valid_0's multi_logloss: 1.51598
# [260]	valid_0's multi_logloss: 1.51583
# [261]	valid_0's multi_logloss: 1.51564
# [262]	valid_0's multi_logloss: 1.5155
# [263]	valid_0's multi_logloss: 1.51536
# [264]	valid_0's multi_logloss: 1.51517
# [265]	valid_0's multi_logloss: 1.51501
# [266]	valid_0's multi_logloss: 1.5148
# [267]	valid_0's multi_logloss: 1.51463
# [268]	valid_0's multi_logloss: 1.51442
# [269]	valid_0's multi_logloss: 1.51423
# [270]	valid_0's multi_logloss: 1.51405
# [271]	valid_0's multi_logloss: 1.51389
# [272]	valid_0's multi_logloss: 1.51371
# [273]	valid_0's multi_logloss: 1.51352
# [274]	valid_0's multi_logloss: 1.51332
# [275]	valid_0's multi_logloss: 1.51313
# [276]	valid_0's multi_logloss: 1.51295
# [277]	valid_0's multi_logloss: 1.51277
# [278]	valid_0's multi_logloss: 1.51264
# [279]	valid_0's multi_logloss: 1.5124
# [280]	valid_0's multi_logloss: 1.51222
# [281]	valid_0's multi_logloss: 1.51203
# [282]	valid_0's multi_logloss: 1.51183
# [283]	valid_0's multi_logloss: 1.51164
# [284]	valid_0's multi_logloss: 1.51149
# [285]	valid_0's multi_logloss: 1.5113
# [286]	valid_0's multi_logloss: 1.51114
# [287]	valid_0's multi_logloss: 1.51103
# [288]	valid_0's multi_logloss: 1.51085
# [289]	valid_0's multi_logloss: 1.5107
# [290]	valid_0's multi_logloss: 1.51049
# [291]	valid_0's multi_logloss: 1.51035
# [292]	valid_0's multi_logloss: 1.51013
# [293]	valid_0's multi_logloss: 1.50995
# [294]	valid_0's multi_logloss: 1.50977
# [295]	valid_0's multi_logloss: 1.50956
# [296]	valid_0's multi_logloss: 1.50938
# [297]	valid_0's multi_logloss: 1.50921
# [298]	valid_0's multi_logloss: 1.50906
# [299]	valid_0's multi_logloss: 1.50891
# [300]	valid_0's multi_logloss: 1.50872
# [301]	valid_0's multi_logloss: 1.50859
# [302]	valid_0's multi_logloss: 1.5084
# [303]	valid_0's multi_logloss: 1.50822
# [304]	valid_0's multi_logloss: 1.50806
# [305]	valid_0's multi_logloss: 1.5079
# [306]	valid_0's multi_logloss: 1.50768
# [307]	valid_0's multi_logloss: 1.50752
# [308]	valid_0's multi_logloss: 1.50737
# [309]	valid_0's multi_logloss: 1.50719
# [310]	valid_0's multi_logloss: 1.50704
# [311]	valid_0's multi_logloss: 1.5069
# [312]	valid_0's multi_logloss: 1.5067
# [313]	valid_0's multi_logloss: 1.5065
# [314]	valid_0's multi_logloss: 1.5063
# [315]	valid_0's multi_logloss: 1.50612
# [316]	valid_0's multi_logloss: 1.50598
# [317]	valid_0's multi_logloss: 1.50577
# [318]	valid_0's multi_logloss: 1.50559
# [319]	valid_0's multi_logloss: 1.50539
# [320]	valid_0's multi_logloss: 1.50525
# [321]	valid_0's multi_logloss: 1.50507
# [322]	valid_0's multi_logloss: 1.50494
# [323]	valid_0's multi_logloss: 1.50469
# [324]	valid_0's multi_logloss: 1.50452
# [325]	valid_0's multi_logloss: 1.5043
# [326]	valid_0's multi_logloss: 1.50415
# [327]	valid_0's multi_logloss: 1.50392
# [328]	valid_0's multi_logloss: 1.50374
# [329]	valid_0's multi_logloss: 1.5036
# [330]	valid_0's multi_logloss: 1.50348
# [331]	valid_0's multi_logloss: 1.50331
# [332]	valid_0's multi_logloss: 1.50318
# [333]	valid_0's multi_logloss: 1.50304
# [334]	valid_0's multi_logloss: 1.50286
# [335]	valid_0's multi_logloss: 1.50271
# [336]	valid_0's multi_logloss: 1.50258
# [337]	valid_0's multi_logloss: 1.50245
# [338]	valid_0's multi_logloss: 1.50229
# [339]	valid_0's multi_logloss: 1.50211
# [340]	valid_0's multi_logloss: 1.50197
# [341]	valid_0's multi_logloss: 1.50181
# [342]	valid_0's multi_logloss: 1.50167
# [343]	valid_0's multi_logloss: 1.50146
# [344]	valid_0's multi_logloss: 1.50127
# [345]	valid_0's multi_logloss: 1.50107
# [346]	valid_0's multi_logloss: 1.50087
# [347]	valid_0's multi_logloss: 1.50072
# [348]	valid_0's multi_logloss: 1.50058
# [349]	valid_0's multi_logloss: 1.50044
# [350]	valid_0's multi_logloss: 1.5003
# [351]	valid_0's multi_logloss: 1.50016
# [352]	valid_0's multi_logloss: 1.5
# [353]	valid_0's multi_logloss: 1.49979
# [354]	valid_0's multi_logloss: 1.49962
# [355]	valid_0's multi_logloss: 1.49943
# [356]	valid_0's multi_logloss: 1.49925
# [357]	valid_0's multi_logloss: 1.49911
# [358]	valid_0's multi_logloss: 1.4989
# [359]	valid_0's multi_logloss: 1.49868
# [360]	valid_0's multi_logloss: 1.49851
# [361]	valid_0's multi_logloss: 1.49832
# [362]	valid_0's multi_logloss: 1.49815
# [363]	valid_0's multi_logloss: 1.49793
# [364]	valid_0's multi_logloss: 1.49775
# [365]	valid_0's multi_logloss: 1.49761
# [366]	valid_0's multi_logloss: 1.49744
# [367]	valid_0's multi_logloss: 1.49728
# [368]	valid_0's multi_logloss: 1.4971
# [369]	valid_0's multi_logloss: 1.49691
# [370]	valid_0's multi_logloss: 1.49674
# [371]	valid_0's multi_logloss: 1.49657
# [372]	valid_0's multi_logloss: 1.4964
# [373]	valid_0's multi_logloss: 1.49625
# [374]	valid_0's multi_logloss: 1.4961
# [375]	valid_0's multi_logloss: 1.49595
# [376]	valid_0's multi_logloss: 1.49582
# [377]	valid_0's multi_logloss: 1.49567
# [378]	valid_0's multi_logloss: 1.49549
# [379]	valid_0's multi_logloss: 1.49534
# [380]	valid_0's multi_logloss: 1.49517
# [381]	valid_0's multi_logloss: 1.49499
# [382]	valid_0's multi_logloss: 1.4948
# [383]	valid_0's multi_logloss: 1.49465
# [384]	valid_0's multi_logloss: 1.49448
# [385]	valid_0's multi_logloss: 1.49434
# [386]	valid_0's multi_logloss: 1.49418
# [387]	valid_0's multi_logloss: 1.49397
# [388]	valid_0's multi_logloss: 1.49376
# [389]	valid_0's multi_logloss: 1.4936
# [390]	valid_0's multi_logloss: 1.49339
# [391]	valid_0's multi_logloss: 1.49325
# [392]	valid_0's multi_logloss: 1.49309
# [393]	valid_0's multi_logloss: 1.49293
# [394]	valid_0's multi_logloss: 1.49271
# [395]	valid_0's multi_logloss: 1.49256
# [396]	valid_0's multi_logloss: 1.49238
# [397]	valid_0's multi_logloss: 1.49218
# [398]	valid_0's multi_logloss: 1.49199
# [399]	valid_0's multi_logloss: 1.49181
# [400]	valid_0's multi_logloss: 1.49165
# [401]	valid_0's multi_logloss: 1.49149
# [402]	valid_0's multi_logloss: 1.49135
# [403]	valid_0's multi_logloss: 1.49114
# [404]	valid_0's multi_logloss: 1.49097
# [405]	valid_0's multi_logloss: 1.49081
# [406]	valid_0's multi_logloss: 1.49066
# [407]	valid_0's multi_logloss: 1.49048
# [408]	valid_0's multi_logloss: 1.49032
# [409]	valid_0's multi_logloss: 1.49013
# [410]	valid_0's multi_logloss: 1.48997
# [411]	valid_0's multi_logloss: 1.48983
# [412]	valid_0's multi_logloss: 1.48967
# [413]	valid_0's multi_logloss: 1.48949
# [414]	valid_0's multi_logloss: 1.48932
# [415]	valid_0's multi_logloss: 1.48915
# [416]	valid_0's multi_logloss: 1.48899
# [417]	valid_0's multi_logloss: 1.48881
# [418]	valid_0's multi_logloss: 1.48863
# [419]	valid_0's multi_logloss: 1.48851
# [420]	valid_0's multi_logloss: 1.48836
# [421]	valid_0's multi_logloss: 1.4882
# [422]	valid_0's multi_logloss: 1.48809
# [423]	valid_0's multi_logloss: 1.48789
# [424]	valid_0's multi_logloss: 1.48776
# [425]	valid_0's multi_logloss: 1.48759
# [426]	valid_0's multi_logloss: 1.48741
# [427]	valid_0's multi_logloss: 1.48725
# [428]	valid_0's multi_logloss: 1.48711
# [429]	valid_0's multi_logloss: 1.48698
# [430]	valid_0's multi_logloss: 1.48683
# [431]	valid_0's multi_logloss: 1.48671
# [432]	valid_0's multi_logloss: 1.48656
# [433]	valid_0's multi_logloss: 1.48638
# [434]	valid_0's multi_logloss: 1.48623
# [435]	valid_0's multi_logloss: 1.48603
# [436]	valid_0's multi_logloss: 1.48588
# [437]	valid_0's multi_logloss: 1.48575
# [438]	valid_0's multi_logloss: 1.48561
# [439]	valid_0's multi_logloss: 1.48546
# [440]	valid_0's multi_logloss: 1.48534
# [441]	valid_0's multi_logloss: 1.48515
# [442]	valid_0's multi_logloss: 1.485
# [443]	valid_0's multi_logloss: 1.48487
# [444]	valid_0's multi_logloss: 1.48471
# [445]	valid_0's multi_logloss: 1.48458
# [446]	valid_0's multi_logloss: 1.48442
# [447]	valid_0's multi_logloss: 1.48427
# [448]	valid_0's multi_logloss: 1.48415
# [449]	valid_0's multi_logloss: 1.48398
# [450]	valid_0's multi_logloss: 1.48382
# [451]	valid_0's multi_logloss: 1.48367
# [452]	valid_0's multi_logloss: 1.4835
# [453]	valid_0's multi_logloss: 1.48334
# [454]	valid_0's multi_logloss: 1.48315
# [455]	valid_0's multi_logloss: 1.483
# [456]	valid_0's multi_logloss: 1.48286
# [457]	valid_0's multi_logloss: 1.48268
# [458]	valid_0's multi_logloss: 1.48251
# [459]	valid_0's multi_logloss: 1.48235
# [460]	valid_0's multi_logloss: 1.48221
# [461]	valid_0's multi_logloss: 1.48206
# [462]	valid_0's multi_logloss: 1.48187
# [463]	valid_0's multi_logloss: 1.48173
# [464]	valid_0's multi_logloss: 1.48161
# [465]	valid_0's multi_logloss: 1.48144
# [466]	valid_0's multi_logloss: 1.48125
# [467]	valid_0's multi_logloss: 1.48112
# [468]	valid_0's multi_logloss: 1.48097
# [469]	valid_0's multi_logloss: 1.4808
# [470]	valid_0's multi_logloss: 1.48065
# [471]	valid_0's multi_logloss: 1.48047
# [472]	valid_0's multi_logloss: 1.4803
# [473]	valid_0's multi_logloss: 1.48016
# [474]	valid_0's multi_logloss: 1.47999
# [475]	valid_0's multi_logloss: 1.47986
# [476]	valid_0's multi_logloss: 1.47969
# [477]	valid_0's multi_logloss: 1.47956
# [478]	valid_0's multi_logloss: 1.47942
# [479]	valid_0's multi_logloss: 1.47925
# [480]	valid_0's multi_logloss: 1.47909
# [481]	valid_0's multi_logloss: 1.47893
# [482]	valid_0's multi_logloss: 1.47881
# [483]	valid_0's multi_logloss: 1.47865
# [484]	valid_0's multi_logloss: 1.47851
# [485]	valid_0's multi_logloss: 1.47835
# [486]	valid_0's multi_logloss: 1.47818
# [487]	valid_0's multi_logloss: 1.47805
# [488]	valid_0's multi_logloss: 1.4779
# [489]	valid_0's multi_logloss: 1.47773
# [490]	valid_0's multi_logloss: 1.47756
# [491]	valid_0's multi_logloss: 1.47744
# [492]	valid_0's multi_logloss: 1.4773
# [493]	valid_0's multi_logloss: 1.47718
# [494]	valid_0's multi_logloss: 1.47705
# [495]	valid_0's multi_logloss: 1.47691
# [496]	valid_0's multi_logloss: 1.47678
# [497]	valid_0's multi_logloss: 1.47661
# [498]	valid_0's multi_logloss: 1.47649
# [499]	valid_0's multi_logloss: 1.47634
# [500]	valid_0's multi_logloss: 1.47621
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's multi_logloss: 1.47621

# %%
predictions = []
for x in gbm.predict(x_train):
    predictions.append(np.argmax(x))

y_train_pred = np.array(predictions).reshape(-1)
y_train_true = y_train

from sklearn.metrics import confusion_matrix
print("== Train Obs ==")
print('{:,} obs' .format(len(x_train)), end="\n\n")
print("== Train Error Matrix ==")
print(confusion_matrix(y_train_true, y_train_pred), end="\n\n")
print("== Train Accuracy ==")
acc = (8822 + 8666 + 243487 + 175691 + 85904 + 4567 + 6722) / len(y_train)
print("train accuracy : {:.2f}%" .format(acc * 100))
# Out:
# == Train Obs ==
# 1,259,136 obs
#
# == Train Error Matrix ==
# [[  8822    671  20917   2853   3229     22    132]
#  [  1232   8666  72477   9032  11729     57    214]
#  [  1087    915 243487  64557  30189    132    280]
#  [   690    566 133601 175691  35191    139    242]
#  [   783    689 135554  68358  85904    160    297]
#  [   444    389  53295  10613  19337   4567    282]
#  [   460    289  28980   4846  10245    102   6722]]
#
# == Train Accuracy ==
# train accuracy : 42.40%

# %%
predictions = []
for x in gbm.predict(x_valid):
    predictions.append(np.argmax(x))

y_valid_pred = np.array(predictions).reshape(-1)
y_valid_true = y_valid

from sklearn.metrics import confusion_matrix
print("== Valid Obs ==")
print('{:,} obs' .format(len(x_valid)), end="\n\n")
print("== Valid Error Matrix ==")
print(confusion_matrix(y_valid_true, y_valid_pred), end="\n\n")
print("== Valid Accuracy ==")
acc = (1605 + 1437 + 58757 + 41977 + 18551 + 634 + 1037) / len(y_valid)
print("valid accuracy : {:.2f}%" .format(acc * 100))
# Out:
# == Valid Obs ==
# 314,784 obs
#
# == Valid Error Matrix ==
# [[ 1605   241  5653   761   843     8    35]
#  [  364  1437 18471  2306  3107    17    86]
#  [  340   361 58757 17041  8926    42    90]
#  [  217   216 34701 41977  9546    41    68]
#  [  233   227 35671 17980 18551    65   129]
#  [  140   127 13350  2682  5036   634   110]
#  [  144    98  7342  1243  2682    46  1037]]
#
# == Valid Accuracy ==
# valid accuracy : 39.39%

# %%
predictions = []
for x in gbm.predict(x_test):
    predictions.append(np.argmax(x))

y_test_pred = np.array(predictions).reshape(-1)
y_test_true = y_test

from sklearn.metrics import confusion_matrix
print("== Test Obs ==")
print('{:,} obs' .format(len(x_test)), end="\n\n")
print("== Test Error Matrix ==")
print(confusion_matrix(y_test_true, y_test_pred), end="\n\n")
print("== Test Accuracy ==")
acc = (828 + 802 + 32689 + 23706 + 10423 + 318 + 600) / len(y_test)
print("test accuracy : {:.2f}" .format(acc * 100))
# Out:
# == Test Obs ==
# 174,880 obs
#
# == Test Error Matrix ==
# [[  828   139  3031   391   491     2    31]
#  [  221   802 10309  1315  1724    12    50]
#  [  184   205 32689  9556  4887    32    59]
#  [  113    96 19175 23706  5181    27    44]
#  [  133   117 19525  9899 10423    36    54]
#  [   66    74  7364  1516  2812   318    43]
#  [   73    60  4160   706  1580    21   600]]
#
# == Test Accuracy ==
# test accuracy : 39.66

# %%
heatmap =pd.DataFrame(confusion_matrix(y_test_true, y_test_pred),
                      columns=['-Inf ~ -10.00', '-10.00 ~ -5.00', '-4.99 ~ -1.00', '-1.00 ~ 1.00', '1.00 ~ 5.00', '5.00 ~ 10.00', '10.0 ~ Inf'],
                      index = ['-Inf ~ -10.00', '-10.00 ~ -5.00', '-4.99 ~ -1.00', '-1.00 ~ 1.00', '1.00 ~ 5.00', '5.00 ~ 10.00', '10.0 ~ Inf'])

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(10,6))
map = sns.heatmap(heatmap, annot=True, fmt="d", linewidths=.5, ax=ax, cmap='coolwarm')
map.set_ylim(7,0)
plt.show()

# %% [markdown]
# ### Test 상승, 하락, 변화없음 3 Class로만 분류한 경우

# %%
Class3 = np.array([[828+139+3031+221+802+10309+184+205+32689, 391+1315+9556, 491+2+31+1724+12+50+4887+32+59],
                   [113+96+19175, 23706, 5181+27+44],
                   [133+117+19525+66+74+7364+73+60+4160, 9899+1516+706, 10423+36+54+2812+318+43+1580+21+600]])

print("== Up and Not and Down ==")
print(Class3, end="\n\n")

acc = (48408+23706+15887) / (48408+11262+7288+19384+23706+15252+31572+12121+15887)

print("Test 3 Class Accuracy = {:.2f}%". format(acc*100))
# Out:
# == Up and Not and Down ==
# [[48408 11262  7288]
#  [19384 23706  5252]
#  [31572 12121 15887]]
#
# Test 3 Class Accuracy = 47.60

# %%
heatmap =pd.DataFrame(Class3,
                      columns=['Down', 'Not', 'Up'],
                      index = ['Down', 'Not', 'Up'])

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(10,6))
map = sns.heatmap(heatmap, annot=True, fmt="d", linewidths=.5, ax=ax, cmap='coolwarm')
map.set_ylim(3,0)
plt.show()
