# %% [markdown]
# ### 1. Setting

# %%
# Seed
from numpy.random import seed
seed(1234)
from tensorflow import set_random_seed
set_random_seed(1234)

# %%
# Warning Message
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### 2. Data Loading

# %%
# Original 데이터
import pandas as pd
data_original_2017 = pd.read_csv('./data/original_data_2017.csv')
data_original_2018 = pd.read_csv('./data/original_data_2018.csv')
data_original_2019 = pd.read_csv('./data/original_data_2019.csv')

# %%
# 사내 창출 데이터
import pandas as pd
data_new_2017 = pd.read_csv('./data/new_data_2017.csv')
data_new_2018 = pd.read_csv('./data/new_data_2017.csv')
data_new_2019 = pd.read_csv('./data/new_data_2017.csv')

# %%
# Unnamed 칼럼 제거
data_original_2017 = data_original_2017[data_original_2017.columns[1:]]
data_new_2017 = data_new_2017[data_new_2017.columns[1:]]

# %% [markdown]
# ### 3. Data Head

# %%
data_original_2017
# Out:
#                        date   open   high    low  close  trading_volume  \
# 0       2017-01-02 00:00:00  79905  81585  79170  79800            2730
# 1       2017-01-03 00:00:00  80535  80535  79170  79800            3093
# 2       2017-01-04 00:00:00  80535  80955  76965  77175            2183
# 3       2017-01-05 00:00:00  77070  78855  75600  78225            2560
# 4       2017-01-06 00:00:00  78225  79800  77280  77385            2386
# ...                     ...    ...    ...    ...    ...             ...
# 587160  2017-12-21 00:00:00  11550  11950  10500  10600         1305109
# 587161  2017-12-22 00:00:00  10300  11250   9650   9960         1040672
# 587162  2017-12-26 00:00:00  10150  10350   9410   9410          481185
# 587163  2017-12-27 00:00:00   9540  11650   9470   9750         5397011
# 587164  2017-12-28 00:00:00   9880  10600   9780  10050          912331
#
#         trading_value    code
# 0        2.082262e+08   12320
# 1        2.353751e+08   12320
# 2        1.625183e+08   12320
# 3        1.881497e+08   12320
# 4        1.782250e+08   12320
# ...               ...     ...
# 587160   1.447922e+10  187870
# 587161   1.074168e+10  187870
# 587162   4.688869e+09  187870
# 587163   5.784463e+10  187870
# 587164   9.164236e+09  187870
#
# [587165 rows x 8 columns]

# %%
data_new_2017
# Out:
#                        date    kindex     index     score  probability    code
# 0       2017-01-02 00:00:00  0.000685  0.388889  0.546392     6.863271   12320
# 1       2017-01-03 00:00:00  0.000685  0.388889  0.546392     6.863271   12320
# 2       2017-01-04 00:00:00  0.001262  0.555556  0.974026     3.584906   12320
# 3       2017-01-05 00:00:00  0.001213  0.625000  0.948718     8.089888   12320
# 4       2017-01-06 00:00:00  0.001226  0.625000  0.948718     8.089888   12320
# ...                     ...       ...       ...       ...          ...     ...
# 587160  2017-12-21 00:00:00  0.009434  1.000000  1.000000    30.000000  187870
# 587161  2017-12-22 00:00:00  0.010040  1.000000  1.000000    30.000000  187870
# 587162  2017-12-26 00:00:00  0.010627  1.000000  1.000000    30.000000  187870
# 587163  2017-12-27 00:00:00  0.010256  1.000000  1.000000    30.000000  187870
# 587164  2017-12-28 00:00:00  0.009950  1.000000  1.000000    30.000000  187870
#
# [587165 rows x 6 columns]

# %% [markdown]
# ### 4. Code

# %%
CODE_LIST = data_new_2019.code.value_counts().index

# %% [markdown]
# ### 5. Data Merge & Labeling

# %%
stock_data = pd.DataFrame()
df_final = pd.DataFrame()
NUM = 0

for code in CODE_LIST[:] :
    
    # 2017
    data_original = data_original_2017[data_original_2017['code'] == code]
    data_new = data_new_2017[data_new_2017['code'] == code]
    data = pd.merge(data_original, data_new, how='left')
    data = data[['date','trading_volume', 'trading_value', 'kindex', 'index', 'score', 'probability', 'close']]
    df_final = df_final.append(data)
    
    # 2018
    data_original = data_original_2018[data_original_2018['code'] == code]
    data_new = data_new_2018[data_new_2018['code'] == code]
    data = pd.merge(data_original, data_new, how='left')
    data = data[['date','trading_volume', 'trading_value', 'kindex', 'index', 'score', 'probability', 'close']]
    df_final = df_final.append(data)
    
    # 2019
    data_original = data_original_2019[data_original_2019['code'] == code]
    data_new = data_new_2019[data_new_2019['code'] == code]
    data = pd.merge(data_original, data_new, how='left')
    data = data[['date','trading_volume', 'trading_value', 'kindex', 'index', 'score', 'probability', 'close']]
    df_final = df_final.append(data)
    
    # Index Reset
    df_final = df_final.reset_index()
    
    # Data Shfit 생성    
    df_final['close5'] = df_final['close'].shift(-5)
    df_final['pred_rate'] = (100 * (df_final['close5'] - df_final['close'])) / df_final['close']
    df_final = df_final[:-5]

    # 예측값 라벨링
    def labeling(x) : 
        if x >= 15.00 : 
            result = '15 ~ Inf'
        elif x >= 12.00 : 
            result = '12 ~ 15'
        elif x >= 9.00 : 
            result = '9 ~ 12'
        elif x >= 6.00 : 
            result = '6 ~ 9'
        elif x >= 3.00 : 
            result = '3 ~ 6'
        elif x >= 0 : 
            result = '0 ~ 3'
        elif x >= -3.00 : 
            result = '-3 ~ 0'
        elif x >= -6.00 : 
            result = '-6 ~ -3'
        elif x >= -9.00 : 
            result = '-9 ~ -6'
        elif x >= -12.00 : 
            result = '-12 ~ -9'
        elif x >= -15.00 : 
            result = '-15 ~ -12'
        else : 
            result = '-INF ~ -15'
        return result

    # 함수 적용
    df_final['pred_rate_label'] = df_final['pred_rate'].apply(lambda x : labeling(x))
    
    # Feature Selecting
    df_final = df_final[['trading_volume', 'trading_value', 'kindex', 'index', 'score', 'probability', 'pred_rate_label']]

    # MinMaxScaling
    from sklearn.preprocessing import MinMaxScaler
    scaler = MinMaxScaler()
    scaler.fit(df_final[['trading_volume', 'trading_value', 'kindex', 'index', 'score', 'probability']])
    X = scaler.transform(df_final[['trading_volume', 'trading_value', 'kindex', 'index', 'score', 'probability']])
    y = df_final[['pred_rate_label']]
    df_final_X = pd.DataFrame(X, columns=['trading_volume', 'trading_value', 'kindex', 'index', 'score', 'probability'])
    df_final_y = pd.DataFrame(y, columns=['pred_rate_label'])
    df_final = pd.concat([df_final_X, df_final_y], axis=1)
    
    # 최종 데이터셋에 추가
    stock_data = stock_data.append(df_final)
    
    # df_final Reset
    df_final = pd.DataFrame()
    
    # 경과 check
    if NUM % 100 == 0 : 
        print("{:4}번째 종목 계산 중...." .format(NUM))
    NUM += 1

# 결측값 제거
stock_data = stock_data.dropna(axis=0)

# 최종 데이터 인덱스 리셋
stock_data = stock_data.reset_index()

# Final Data
stock_data = stock_data[['trading_volume', 'trading_value', 'kindex', 'index', 'score', 'probability', 'pred_rate_label']]
# Out:
#    0번째 종목 계산 중....
#  100번째 종목 계산 중....
#  200번째 종목 계산 중....
#  300번째 종목 계산 중....
#  400번째 종목 계산 중....
#  500번째 종목 계산 중....
#  600번째 종목 계산 중....
#  700번째 종목 계산 중....
#  800번째 종목 계산 중....
#  900번째 종목 계산 중....
# 1000번째 종목 계산 중....
# 1100번째 종목 계산 중....
# 1200번째 종목 계산 중....
# 1300번째 종목 계산 중....
# 1400번째 종목 계산 중....
# 1500번째 종목 계산 중....
# 1600번째 종목 계산 중....
# 1700번째 종목 계산 중....
# 1800번째 종목 계산 중....
# 1900번째 종목 계산 중....
# 2000번째 종목 계산 중....
# 2100번째 종목 계산 중....
# 2200번째 종목 계산 중....
# 2300번째 종목 계산 중....
# 2400번째 종목 계산 중....
# 2500번째 종목 계산 중....

# %%
stock_data
# Out:
#         trading_volume  trading_value    kindex     index     score  \
# 0             0.000887       0.000284  0.002800  0.020243  0.002881
# 1             0.000965       0.000308  0.002800  0.020243  0.002881
# 2             0.001138       0.000362  0.002800  0.020243  0.002881
# 3             0.001045       0.000331  0.003382  0.027665  0.003482
# 4             0.001190       0.000376  0.005843  0.035088  0.006026
# ...                ...            ...       ...       ...       ...
# 587070        0.000000       0.000000  0.868226  0.000000  0.000000
# 587071        0.000107       0.000112  0.000000  0.000000  0.000000
# 587072        0.760873       0.788579  0.000000  0.000000  0.000000
# 587073        0.339865       0.355151  0.827286  1.000000  1.000000
# 587074        0.436664       0.482350  1.000000  1.000000  1.000000
#
#         probability pred_rate_label
# 0          0.352102          -3 ~ 0
# 1          0.352102          -3 ~ 0
# 2          0.352102          -3 ~ 0
# 3          0.451567          -3 ~ 0
# 4          0.534200          -3 ~ 0
# ...             ...             ...
# 587070     0.000000           6 ~ 9
# 587071     0.000000           3 ~ 6
# 587072     0.000000        15 ~ Inf
# 587073     1.000000        -12 ~ -9
# 587074     1.000000           3 ~ 6
#
# [587075 rows x 7 columns]

# %%
stock_data.describe()
# Out:
#        trading_volume  trading_value         kindex          index  \
# count   587075.000000  587075.000000  587075.000000  587075.000000
# mean         0.044676       0.044539       0.230653       0.195274
# std          0.093393       0.094332       0.333281       0.276289
# min          0.000000       0.000000       0.000000       0.000000
# 25%          0.003416       0.002757       0.000299       0.017336
# 50%          0.012344       0.011278       0.001612       0.059075
# 75%          0.043671       0.043342       0.514467       0.254089
# max          1.000000       1.000000       1.000000       1.000000
#
#                score    probability
# count  587075.000000  587075.000000
# mean        0.217463       0.640102
# std         0.329985       0.368791
# min         0.000000       0.000000
# 25%         0.000238       0.285012
# 50%         0.001406       0.875592
# 75%         0.467181       0.985024
# max         1.000000       1.000000

# %%
import matplotlib.pyplot as plt
label_count = pd.DataFrame([stock_data.pred_rate_label.value_counts()]).T
label_count['label'] = label_count.index
plt.figure(figsize=(18,6))
import seaborn as sns
sns.set(style = 'whitegrid')
ax = sns.barplot(x='label', y='pred_rate_label', data=label_count)

# %%
# Label Setting
def label_to_numeric(x) : 
    if x == '-INF ~ -15' : 
        result = 0
    elif x == '-15 ~ -12' : 
        result = 1
    elif x == '-12 ~ -9' : 
        result = 2
    elif x == '-9 ~ -6' : 
        result = 3
    elif x == '-6 ~ -3' : 
        result = 4
    elif x == '-3 ~ 0' : 
        result = 5
    elif x == '0 ~ 3' : 
        result = 6
    elif x == '3 ~ 6' : 
        result = 7
    elif x == '6 ~ 9' : 
        result = 8
    elif x == '9 ~ 12' : 
        result = 9
    elif x == '12 ~ 15' : 
        result = 10
    else : 
        result = 11
    return result
        
# 함수 적용
stock_data['label'] = stock_data['pred_rate_label'].apply(lambda x : label_to_numeric(x))
stock_data
# Out:
#         trading_volume  trading_value    kindex     index     score  \
# 0             0.000887       0.000284  0.002800  0.020243  0.002881
# 1             0.000965       0.000308  0.002800  0.020243  0.002881
# 2             0.001138       0.000362  0.002800  0.020243  0.002881
# 3             0.001045       0.000331  0.003382  0.027665  0.003482
# 4             0.001190       0.000376  0.005843  0.035088  0.006026
# ...                ...            ...       ...       ...       ...
# 587070        0.000000       0.000000  0.868226  0.000000  0.000000
# 587071        0.000107       0.000112  0.000000  0.000000  0.000000
# 587072        0.760873       0.788579  0.000000  0.000000  0.000000
# 587073        0.339865       0.355151  0.827286  1.000000  1.000000
# 587074        0.436664       0.482350  1.000000  1.000000  1.000000
#
#         probability pred_rate_label  label
# 0          0.352102          -3 ~ 0      5
# 1          0.352102          -3 ~ 0      5
# 2          0.352102          -3 ~ 0      5
# 3          0.451567          -3 ~ 0      5
# 4          0.534200          -3 ~ 0      5
# ...             ...             ...    ...
# 587070     0.000000           6 ~ 9      8
# 587071     0.000000           3 ~ 6      7
# 587072     0.000000        15 ~ Inf     11
# 587073     1.000000        -12 ~ -9      2
# 587074     1.000000           3 ~ 6      7
#
# [587075 rows x 8 columns]

# %% [markdown]
# ### LightGBM

# %%
# Train Test Split
from sklearn.model_selection import train_test_split
X = stock_data[['trading_volume', 'trading_value', 'kindex', 'index', 'score', 'probability']].values
y = stock_data[['label']].values
y = y.reshape(-1)
x_train, x_test, y_train, y_test = train_test_split(X, y,test_size=0.1, random_state=1234)
x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train ,test_size=0.2, random_state=1234)

# HyperParameter
params = {
    'task' : 'train',
    'boosting_type' : 'gbdt',
    'objective' : 'multiclass',
    'metric' : {'multi_logloss'},
    'num_leaves' : 63,
    'learning_rate' : 0.05,
    'feature_fraction' : 0.9,
    'bagging_fraction' : 0.9,
    'bagging_freq': 0,
    'verbose' : 1,
    'num_class' : 12,
    'save_binary' : True,
    'device' : 'gpu'
}

# Model Fitting
import lightgbm as lgb
lgb_train = lgb.Dataset(x_train, y_train)
lgb_eval = lgb.Dataset(x_test, y_test, reference=lgb_train)
gbm = lgb.train(params,
                lgb_train,
                num_boost_round=1000,
                valid_sets=lgb_eval,
                early_stopping_rounds = 30)
# Out:
# [1]	valid_0's multi_logloss: 1.82217
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's multi_logloss: 1.81826
# [3]	valid_0's multi_logloss: 1.8149
# [4]	valid_0's multi_logloss: 1.81157
# [5]	valid_0's multi_logloss: 1.8084
# [6]	valid_0's multi_logloss: 1.80542
# [7]	valid_0's multi_logloss: 1.80278
# [8]	valid_0's multi_logloss: 1.80014
# [9]	valid_0's multi_logloss: 1.7979
# [10]	valid_0's multi_logloss: 1.79565
# [11]	valid_0's multi_logloss: 1.79349
# [12]	valid_0's multi_logloss: 1.79147
# [13]	valid_0's multi_logloss: 1.78947
# [14]	valid_0's multi_logloss: 1.7877
# [15]	valid_0's multi_logloss: 1.78582
# [16]	valid_0's multi_logloss: 1.78407
# [17]	valid_0's multi_logloss: 1.78247
# [18]	valid_0's multi_logloss: 1.78087
# [19]	valid_0's multi_logloss: 1.77935
# [20]	valid_0's multi_logloss: 1.77791
# [21]	valid_0's multi_logloss: 1.7765
# [22]	valid_0's multi_logloss: 1.77522
# [23]	valid_0's multi_logloss: 1.77394
# [24]	valid_0's multi_logloss: 1.77271
# [25]	valid_0's multi_logloss: 1.77157
# [26]	valid_0's multi_logloss: 1.7704
# [27]	valid_0's multi_logloss: 1.76928
# [28]	valid_0's multi_logloss: 1.76814
# [29]	valid_0's multi_logloss: 1.76708
# [30]	valid_0's multi_logloss: 1.76607
# [31]	valid_0's multi_logloss: 1.76512
# [32]	valid_0's multi_logloss: 1.76417
# [33]	valid_0's multi_logloss: 1.76325
# [34]	valid_0's multi_logloss: 1.76244
# [35]	valid_0's multi_logloss: 1.76156
# [36]	valid_0's multi_logloss: 1.76079
# [37]	valid_0's multi_logloss: 1.76006
# [38]	valid_0's multi_logloss: 1.75932
# [39]	valid_0's multi_logloss: 1.75859
# [40]	valid_0's multi_logloss: 1.75791
# [41]	valid_0's multi_logloss: 1.7572
# [42]	valid_0's multi_logloss: 1.75656
# [43]	valid_0's multi_logloss: 1.75593
# [44]	valid_0's multi_logloss: 1.75533
# [45]	valid_0's multi_logloss: 1.75472
# [46]	valid_0's multi_logloss: 1.75417
# [47]	valid_0's multi_logloss: 1.75364
# [48]	valid_0's multi_logloss: 1.75315
# [49]	valid_0's multi_logloss: 1.75268
# [50]	valid_0's multi_logloss: 1.75217
# [51]	valid_0's multi_logloss: 1.75166
# [52]	valid_0's multi_logloss: 1.75116
# [53]	valid_0's multi_logloss: 1.75075
# [54]	valid_0's multi_logloss: 1.7503
# [55]	valid_0's multi_logloss: 1.74983
# [56]	valid_0's multi_logloss: 1.74942
# [57]	valid_0's multi_logloss: 1.74903
# [58]	valid_0's multi_logloss: 1.74869
# [59]	valid_0's multi_logloss: 1.74825
# [60]	valid_0's multi_logloss: 1.74788
# [61]	valid_0's multi_logloss: 1.74753
# [62]	valid_0's multi_logloss: 1.74717
# [63]	valid_0's multi_logloss: 1.74683
# [64]	valid_0's multi_logloss: 1.74646
# [65]	valid_0's multi_logloss: 1.74608
# [66]	valid_0's multi_logloss: 1.74578
# [67]	valid_0's multi_logloss: 1.74541
# [68]	valid_0's multi_logloss: 1.74511
# [69]	valid_0's multi_logloss: 1.74485
# [70]	valid_0's multi_logloss: 1.74456
# [71]	valid_0's multi_logloss: 1.74421
# [72]	valid_0's multi_logloss: 1.74394
# [73]	valid_0's multi_logloss: 1.74366
# [74]	valid_0's multi_logloss: 1.74335
# [75]	valid_0's multi_logloss: 1.7431
# [76]	valid_0's multi_logloss: 1.74282
# [77]	valid_0's multi_logloss: 1.74253
# [78]	valid_0's multi_logloss: 1.74228
# [79]	valid_0's multi_logloss: 1.74202
# [80]	valid_0's multi_logloss: 1.7418
# [81]	valid_0's multi_logloss: 1.74147
# [82]	valid_0's multi_logloss: 1.74121
# [83]	valid_0's multi_logloss: 1.74097
# [84]	valid_0's multi_logloss: 1.7407
# [85]	valid_0's multi_logloss: 1.74048
# [86]	valid_0's multi_logloss: 1.74027
# [87]	valid_0's multi_logloss: 1.74007
# [88]	valid_0's multi_logloss: 1.73986
# [89]	valid_0's multi_logloss: 1.73968
# [90]	valid_0's multi_logloss: 1.73949
# [91]	valid_0's multi_logloss: 1.73925
# [92]	valid_0's multi_logloss: 1.73903
# [93]	valid_0's multi_logloss: 1.73885
# [94]	valid_0's multi_logloss: 1.73865
# [95]	valid_0's multi_logloss: 1.73845
# [96]	valid_0's multi_logloss: 1.73828
# [97]	valid_0's multi_logloss: 1.73812
# [98]	valid_0's multi_logloss: 1.73791
# [99]	valid_0's multi_logloss: 1.73772
# [100]	valid_0's multi_logloss: 1.73751
# [101]	valid_0's multi_logloss: 1.73734
# [102]	valid_0's multi_logloss: 1.73715
# [103]	valid_0's multi_logloss: 1.73698
# [104]	valid_0's multi_logloss: 1.73679
# [105]	valid_0's multi_logloss: 1.73665
# [106]	valid_0's multi_logloss: 1.7365
# [107]	valid_0's multi_logloss: 1.73632
# [108]	valid_0's multi_logloss: 1.73614
# [109]	valid_0's multi_logloss: 1.73598
# [110]	valid_0's multi_logloss: 1.73579
# [111]	valid_0's multi_logloss: 1.73561
# [112]	valid_0's multi_logloss: 1.73546
# [113]	valid_0's multi_logloss: 1.73532
# [114]	valid_0's multi_logloss: 1.73517
# [115]	valid_0's multi_logloss: 1.735
# [116]	valid_0's multi_logloss: 1.73486
# [117]	valid_0's multi_logloss: 1.7347
# [118]	valid_0's multi_logloss: 1.73462
# [119]	valid_0's multi_logloss: 1.73448
# [120]	valid_0's multi_logloss: 1.73433
# [121]	valid_0's multi_logloss: 1.73417
# [122]	valid_0's multi_logloss: 1.73406
# [123]	valid_0's multi_logloss: 1.7339
# [124]	valid_0's multi_logloss: 1.73379
# [125]	valid_0's multi_logloss: 1.73368
# [126]	valid_0's multi_logloss: 1.73352
# [127]	valid_0's multi_logloss: 1.73334
# [128]	valid_0's multi_logloss: 1.73322
# [129]	valid_0's multi_logloss: 1.73312
# [130]	valid_0's multi_logloss: 1.73301
# [131]	valid_0's multi_logloss: 1.73289
# [132]	valid_0's multi_logloss: 1.73276
# [133]	valid_0's multi_logloss: 1.73264
# [134]	valid_0's multi_logloss: 1.73252
# [135]	valid_0's multi_logloss: 1.73244
# [136]	valid_0's multi_logloss: 1.73237
# [137]	valid_0's multi_logloss: 1.73224
# [138]	valid_0's multi_logloss: 1.73216
# [139]	valid_0's multi_logloss: 1.73204
# [140]	valid_0's multi_logloss: 1.73196
# [141]	valid_0's multi_logloss: 1.73184
# [142]	valid_0's multi_logloss: 1.73177
# [143]	valid_0's multi_logloss: 1.73168
# [144]	valid_0's multi_logloss: 1.73156
# [145]	valid_0's multi_logloss: 1.7315
# [146]	valid_0's multi_logloss: 1.73139
# [147]	valid_0's multi_logloss: 1.73129
# [148]	valid_0's multi_logloss: 1.73119
# [149]	valid_0's multi_logloss: 1.73109
# [150]	valid_0's multi_logloss: 1.731
# [151]	valid_0's multi_logloss: 1.7309
# [152]	valid_0's multi_logloss: 1.73083
# [153]	valid_0's multi_logloss: 1.73075
# [154]	valid_0's multi_logloss: 1.73066
# [155]	valid_0's multi_logloss: 1.73058
# [156]	valid_0's multi_logloss: 1.73047
# [157]	valid_0's multi_logloss: 1.73038
# [158]	valid_0's multi_logloss: 1.7303
# [159]	valid_0's multi_logloss: 1.73023
# [160]	valid_0's multi_logloss: 1.73012
# [161]	valid_0's multi_logloss: 1.73002
# [162]	valid_0's multi_logloss: 1.72996
# [163]	valid_0's multi_logloss: 1.72989
# [164]	valid_0's multi_logloss: 1.72981
# [165]	valid_0's multi_logloss: 1.72975
# [166]	valid_0's multi_logloss: 1.72967
# [167]	valid_0's multi_logloss: 1.72961
# [168]	valid_0's multi_logloss: 1.72956
# [169]	valid_0's multi_logloss: 1.72949
# [170]	valid_0's multi_logloss: 1.72944
# [171]	valid_0's multi_logloss: 1.72938
# [172]	valid_0's multi_logloss: 1.72931
# [173]	valid_0's multi_logloss: 1.72923
# [174]	valid_0's multi_logloss: 1.72915
# [175]	valid_0's multi_logloss: 1.7291
# [176]	valid_0's multi_logloss: 1.72907
# [177]	valid_0's multi_logloss: 1.72898
# [178]	valid_0's multi_logloss: 1.72895
# [179]	valid_0's multi_logloss: 1.72891
# [180]	valid_0's multi_logloss: 1.72885
# [181]	valid_0's multi_logloss: 1.7288
# [182]	valid_0's multi_logloss: 1.72869
# [183]	valid_0's multi_logloss: 1.72864
# [184]	valid_0's multi_logloss: 1.72857
# [185]	valid_0's multi_logloss: 1.72851
# [186]	valid_0's multi_logloss: 1.72843
# [187]	valid_0's multi_logloss: 1.72839
# [188]	valid_0's multi_logloss: 1.72833
# [189]	valid_0's multi_logloss: 1.72826
# [190]	valid_0's multi_logloss: 1.72821
# [191]	valid_0's multi_logloss: 1.72817
# [192]	valid_0's multi_logloss: 1.72808
# [193]	valid_0's multi_logloss: 1.72801
# [194]	valid_0's multi_logloss: 1.72796
# [195]	valid_0's multi_logloss: 1.7279
# [196]	valid_0's multi_logloss: 1.72783
# [197]	valid_0's multi_logloss: 1.72774
# [198]	valid_0's multi_logloss: 1.72769
# [199]	valid_0's multi_logloss: 1.72765
# [200]	valid_0's multi_logloss: 1.72762
# [201]	valid_0's multi_logloss: 1.72755
# [202]	valid_0's multi_logloss: 1.72752
# [203]	valid_0's multi_logloss: 1.72746
# [204]	valid_0's multi_logloss: 1.72742
# [205]	valid_0's multi_logloss: 1.72735
# [206]	valid_0's multi_logloss: 1.72728
# [207]	valid_0's multi_logloss: 1.72723
# [208]	valid_0's multi_logloss: 1.72717
# [209]	valid_0's multi_logloss: 1.72713
# [210]	valid_0's multi_logloss: 1.72707
# [211]	valid_0's multi_logloss: 1.72702
# [212]	valid_0's multi_logloss: 1.72697
# [213]	valid_0's multi_logloss: 1.72692
# [214]	valid_0's multi_logloss: 1.72687
# [215]	valid_0's multi_logloss: 1.72682
# [216]	valid_0's multi_logloss: 1.7268
# [217]	valid_0's multi_logloss: 1.72676
# [218]	valid_0's multi_logloss: 1.72672
# [219]	valid_0's multi_logloss: 1.72672
# [220]	valid_0's multi_logloss: 1.72664
# [221]	valid_0's multi_logloss: 1.72656
# [222]	valid_0's multi_logloss: 1.72646
# [223]	valid_0's multi_logloss: 1.72639
# [224]	valid_0's multi_logloss: 1.72635
# [225]	valid_0's multi_logloss: 1.72631
# [226]	valid_0's multi_logloss: 1.72621
# [227]	valid_0's multi_logloss: 1.72616
# [228]	valid_0's multi_logloss: 1.72611
# [229]	valid_0's multi_logloss: 1.72607
# [230]	valid_0's multi_logloss: 1.72604
# [231]	valid_0's multi_logloss: 1.72601
# [232]	valid_0's multi_logloss: 1.72596
# [233]	valid_0's multi_logloss: 1.72587
# [234]	valid_0's multi_logloss: 1.72581
# [235]	valid_0's multi_logloss: 1.72574
# [236]	valid_0's multi_logloss: 1.7257
# [237]	valid_0's multi_logloss: 1.72564
# [238]	valid_0's multi_logloss: 1.72559
# [239]	valid_0's multi_logloss: 1.72551
# [240]	valid_0's multi_logloss: 1.72548
# [241]	valid_0's multi_logloss: 1.72537
# [242]	valid_0's multi_logloss: 1.72532
# [243]	valid_0's multi_logloss: 1.72529
# [244]	valid_0's multi_logloss: 1.72523
# [245]	valid_0's multi_logloss: 1.72518
# [246]	valid_0's multi_logloss: 1.72515
# [247]	valid_0's multi_logloss: 1.72509
# [248]	valid_0's multi_logloss: 1.72501
# [249]	valid_0's multi_logloss: 1.72496
# [250]	valid_0's multi_logloss: 1.72493
# [251]	valid_0's multi_logloss: 1.7249
# [252]	valid_0's multi_logloss: 1.72486
# [253]	valid_0's multi_logloss: 1.72479
# [254]	valid_0's multi_logloss: 1.72473
# [255]	valid_0's multi_logloss: 1.72468
# [256]	valid_0's multi_logloss: 1.72462
# [257]	valid_0's multi_logloss: 1.72458
# [258]	valid_0's multi_logloss: 1.72451
# [259]	valid_0's multi_logloss: 1.72447
# [260]	valid_0's multi_logloss: 1.7244
# [261]	valid_0's multi_logloss: 1.72438
# [262]	valid_0's multi_logloss: 1.72433
# [263]	valid_0's multi_logloss: 1.72429
# [264]	valid_0's multi_logloss: 1.72427
# [265]	valid_0's multi_logloss: 1.72419
# [266]	valid_0's multi_logloss: 1.72413
# [267]	valid_0's multi_logloss: 1.72408
# [268]	valid_0's multi_logloss: 1.72404
# [269]	valid_0's multi_logloss: 1.72399
# [270]	valid_0's multi_logloss: 1.72395
# [271]	valid_0's multi_logloss: 1.72388
# [272]	valid_0's multi_logloss: 1.72383
# [273]	valid_0's multi_logloss: 1.7238
# [274]	valid_0's multi_logloss: 1.72376
# [275]	valid_0's multi_logloss: 1.72371
# [276]	valid_0's multi_logloss: 1.72366
# [277]	valid_0's multi_logloss: 1.72359
# [278]	valid_0's multi_logloss: 1.72355
# [279]	valid_0's multi_logloss: 1.72351
# [280]	valid_0's multi_logloss: 1.72344
# [281]	valid_0's multi_logloss: 1.7234
# [282]	valid_0's multi_logloss: 1.72336
# [283]	valid_0's multi_logloss: 1.72329
# [284]	valid_0's multi_logloss: 1.72327
# [285]	valid_0's multi_logloss: 1.72321
# [286]	valid_0's multi_logloss: 1.72317
# [287]	valid_0's multi_logloss: 1.72313
# [288]	valid_0's multi_logloss: 1.72311
# [289]	valid_0's multi_logloss: 1.72305
# [290]	valid_0's multi_logloss: 1.72302
# [291]	valid_0's multi_logloss: 1.72299
# [292]	valid_0's multi_logloss: 1.72296
# [293]	valid_0's multi_logloss: 1.72295
# [294]	valid_0's multi_logloss: 1.7229
# [295]	valid_0's multi_logloss: 1.72287
# [296]	valid_0's multi_logloss: 1.72285
# [297]	valid_0's multi_logloss: 1.7228
# [298]	valid_0's multi_logloss: 1.72277
# [299]	valid_0's multi_logloss: 1.72275
# [300]	valid_0's multi_logloss: 1.7227
# [301]	valid_0's multi_logloss: 1.72265
# [302]	valid_0's multi_logloss: 1.7226
# [303]	valid_0's multi_logloss: 1.72256
# [304]	valid_0's multi_logloss: 1.72251
# [305]	valid_0's multi_logloss: 1.72249
# [306]	valid_0's multi_logloss: 1.72246
# [307]	valid_0's multi_logloss: 1.72244
# [308]	valid_0's multi_logloss: 1.72239
# [309]	valid_0's multi_logloss: 1.72237
# [310]	valid_0's multi_logloss: 1.72234
# [311]	valid_0's multi_logloss: 1.72231
# [312]	valid_0's multi_logloss: 1.72229
# [313]	valid_0's multi_logloss: 1.72227
# [314]	valid_0's multi_logloss: 1.72222
# [315]	valid_0's multi_logloss: 1.72219
# [316]	valid_0's multi_logloss: 1.72216
# [317]	valid_0's multi_logloss: 1.72212
# [318]	valid_0's multi_logloss: 1.72207
# [319]	valid_0's multi_logloss: 1.72202
# [320]	valid_0's multi_logloss: 1.72196
# [321]	valid_0's multi_logloss: 1.72194
# [322]	valid_0's multi_logloss: 1.72188
# [323]	valid_0's multi_logloss: 1.72185
# [324]	valid_0's multi_logloss: 1.72183
# [325]	valid_0's multi_logloss: 1.72183
# [326]	valid_0's multi_logloss: 1.7218
# [327]	valid_0's multi_logloss: 1.72177
# [328]	valid_0's multi_logloss: 1.72174
# [329]	valid_0's multi_logloss: 1.72171
# [330]	valid_0's multi_logloss: 1.72168
# [331]	valid_0's multi_logloss: 1.72164
# [332]	valid_0's multi_logloss: 1.72162
# [333]	valid_0's multi_logloss: 1.72158
# [334]	valid_0's multi_logloss: 1.72153
# [335]	valid_0's multi_logloss: 1.72149
# [336]	valid_0's multi_logloss: 1.72146
# [337]	valid_0's multi_logloss: 1.72141
# [338]	valid_0's multi_logloss: 1.72137
# [339]	valid_0's multi_logloss: 1.72133
# [340]	valid_0's multi_logloss: 1.72132
# [341]	valid_0's multi_logloss: 1.72129
# [342]	valid_0's multi_logloss: 1.72126
# [343]	valid_0's multi_logloss: 1.72122
# [344]	valid_0's multi_logloss: 1.7212
# [345]	valid_0's multi_logloss: 1.7212
# [346]	valid_0's multi_logloss: 1.72119
# [347]	valid_0's multi_logloss: 1.72114
# [348]	valid_0's multi_logloss: 1.7211
# [349]	valid_0's multi_logloss: 1.72107
# [350]	valid_0's multi_logloss: 1.72103
# [351]	valid_0's multi_logloss: 1.72097
# [352]	valid_0's multi_logloss: 1.72097
# [353]	valid_0's multi_logloss: 1.72095
# [354]	valid_0's multi_logloss: 1.7209
# [355]	valid_0's multi_logloss: 1.72085
# [356]	valid_0's multi_logloss: 1.72082
# [357]	valid_0's multi_logloss: 1.72079
# [358]	valid_0's multi_logloss: 1.72075
# [359]	valid_0's multi_logloss: 1.72073
# [360]	valid_0's multi_logloss: 1.72068
# [361]	valid_0's multi_logloss: 1.72066
# [362]	valid_0's multi_logloss: 1.72063
# [363]	valid_0's multi_logloss: 1.7206
# [364]	valid_0's multi_logloss: 1.72056
# [365]	valid_0's multi_logloss: 1.72052
# [366]	valid_0's multi_logloss: 1.72052
# [367]	valid_0's multi_logloss: 1.7205
# [368]	valid_0's multi_logloss: 1.72046
# [369]	valid_0's multi_logloss: 1.72045
# [370]	valid_0's multi_logloss: 1.7204
# [371]	valid_0's multi_logloss: 1.72035
# [372]	valid_0's multi_logloss: 1.72032
# [373]	valid_0's multi_logloss: 1.72031
# [374]	valid_0's multi_logloss: 1.72028
# [375]	valid_0's multi_logloss: 1.72023
# [376]	valid_0's multi_logloss: 1.72019
# [377]	valid_0's multi_logloss: 1.72013
# [378]	valid_0's multi_logloss: 1.7201
# [379]	valid_0's multi_logloss: 1.72005
# [380]	valid_0's multi_logloss: 1.72002
# [381]	valid_0's multi_logloss: 1.71999
# [382]	valid_0's multi_logloss: 1.71996
# [383]	valid_0's multi_logloss: 1.71991
# [384]	valid_0's multi_logloss: 1.71987
# [385]	valid_0's multi_logloss: 1.71982
# [386]	valid_0's multi_logloss: 1.7198
# [387]	valid_0's multi_logloss: 1.71975
# [388]	valid_0's multi_logloss: 1.71973
# [389]	valid_0's multi_logloss: 1.7197
# [390]	valid_0's multi_logloss: 1.71967
# [391]	valid_0's multi_logloss: 1.71965
# [392]	valid_0's multi_logloss: 1.71962
# [393]	valid_0's multi_logloss: 1.71959
# [394]	valid_0's multi_logloss: 1.71956
# [395]	valid_0's multi_logloss: 1.71954
# [396]	valid_0's multi_logloss: 1.7195
# [397]	valid_0's multi_logloss: 1.71948
# [398]	valid_0's multi_logloss: 1.71945
# [399]	valid_0's multi_logloss: 1.71939
# [400]	valid_0's multi_logloss: 1.71936
# [401]	valid_0's multi_logloss: 1.71936
# [402]	valid_0's multi_logloss: 1.71932
# [403]	valid_0's multi_logloss: 1.71928
# [404]	valid_0's multi_logloss: 1.71927
# [405]	valid_0's multi_logloss: 1.71925
# [406]	valid_0's multi_logloss: 1.71924
# [407]	valid_0's multi_logloss: 1.71919
# [408]	valid_0's multi_logloss: 1.71916
# [409]	valid_0's multi_logloss: 1.71914
# [410]	valid_0's multi_logloss: 1.7191
# [411]	valid_0's multi_logloss: 1.71908
# [412]	valid_0's multi_logloss: 1.71905
# [413]	valid_0's multi_logloss: 1.719
# [414]	valid_0's multi_logloss: 1.71896
# [415]	valid_0's multi_logloss: 1.71892
# [416]	valid_0's multi_logloss: 1.7189
# [417]	valid_0's multi_logloss: 1.71888
# [418]	valid_0's multi_logloss: 1.71886
# [419]	valid_0's multi_logloss: 1.71883
# [420]	valid_0's multi_logloss: 1.7188
# [421]	valid_0's multi_logloss: 1.71877
# [422]	valid_0's multi_logloss: 1.71875
# [423]	valid_0's multi_logloss: 1.71872
# [424]	valid_0's multi_logloss: 1.7187
# [425]	valid_0's multi_logloss: 1.71866
# [426]	valid_0's multi_logloss: 1.71862
# [427]	valid_0's multi_logloss: 1.7186
# [428]	valid_0's multi_logloss: 1.71858
# [429]	valid_0's multi_logloss: 1.71853
# [430]	valid_0's multi_logloss: 1.7185
# [431]	valid_0's multi_logloss: 1.71848
# [432]	valid_0's multi_logloss: 1.71846
# [433]	valid_0's multi_logloss: 1.71846
# [434]	valid_0's multi_logloss: 1.71844
# [435]	valid_0's multi_logloss: 1.7184
# [436]	valid_0's multi_logloss: 1.71834
# [437]	valid_0's multi_logloss: 1.71832
# [438]	valid_0's multi_logloss: 1.7183
# [439]	valid_0's multi_logloss: 1.7183
# [440]	valid_0's multi_logloss: 1.71828
# [441]	valid_0's multi_logloss: 1.71825
# [442]	valid_0's multi_logloss: 1.71825
# [443]	valid_0's multi_logloss: 1.71821
# [444]	valid_0's multi_logloss: 1.71816
# [445]	valid_0's multi_logloss: 1.71814
# [446]	valid_0's multi_logloss: 1.71812
# [447]	valid_0's multi_logloss: 1.71807
# [448]	valid_0's multi_logloss: 1.71805
# [449]	valid_0's multi_logloss: 1.718
# [450]	valid_0's multi_logloss: 1.71797
# [451]	valid_0's multi_logloss: 1.71791
# [452]	valid_0's multi_logloss: 1.7179
# [453]	valid_0's multi_logloss: 1.71787
# [454]	valid_0's multi_logloss: 1.71785
# [455]	valid_0's multi_logloss: 1.71782
# [456]	valid_0's multi_logloss: 1.7178
# [457]	valid_0's multi_logloss: 1.71776
# [458]	valid_0's multi_logloss: 1.71773
# [459]	valid_0's multi_logloss: 1.71771
# [460]	valid_0's multi_logloss: 1.71768
# [461]	valid_0's multi_logloss: 1.71765
# [462]	valid_0's multi_logloss: 1.71764
# [463]	valid_0's multi_logloss: 1.71761
# [464]	valid_0's multi_logloss: 1.71758
# [465]	valid_0's multi_logloss: 1.71756
# [466]	valid_0's multi_logloss: 1.71752
# [467]	valid_0's multi_logloss: 1.7175
# [468]	valid_0's multi_logloss: 1.71748
# [469]	valid_0's multi_logloss: 1.71744
# [470]	valid_0's multi_logloss: 1.71741
# [471]	valid_0's multi_logloss: 1.71739
# [472]	valid_0's multi_logloss: 1.71735
# [473]	valid_0's multi_logloss: 1.71734
# [474]	valid_0's multi_logloss: 1.71731
# [475]	valid_0's multi_logloss: 1.71728
# [476]	valid_0's multi_logloss: 1.71724
# [477]	valid_0's multi_logloss: 1.71721
# [478]	valid_0's multi_logloss: 1.71719
# [479]	valid_0's multi_logloss: 1.71717
# [480]	valid_0's multi_logloss: 1.71713
# [481]	valid_0's multi_logloss: 1.71709
# [482]	valid_0's multi_logloss: 1.71707
# [483]	valid_0's multi_logloss: 1.71707
# [484]	valid_0's multi_logloss: 1.71705
# [485]	valid_0's multi_logloss: 1.71704
# [486]	valid_0's multi_logloss: 1.71702
# [487]	valid_0's multi_logloss: 1.71698
# [488]	valid_0's multi_logloss: 1.71696
# [489]	valid_0's multi_logloss: 1.71694
# [490]	valid_0's multi_logloss: 1.71694
# [491]	valid_0's multi_logloss: 1.71691
# [492]	valid_0's multi_logloss: 1.71691
# [493]	valid_0's multi_logloss: 1.71689
# [494]	valid_0's multi_logloss: 1.71682
# [495]	valid_0's multi_logloss: 1.71679
# [496]	valid_0's multi_logloss: 1.71679
# [497]	valid_0's multi_logloss: 1.71678
# [498]	valid_0's multi_logloss: 1.71677
# [499]	valid_0's multi_logloss: 1.71674
# [500]	valid_0's multi_logloss: 1.71669
# [501]	valid_0's multi_logloss: 1.71666
# [502]	valid_0's multi_logloss: 1.71665
# [503]	valid_0's multi_logloss: 1.71659
# [504]	valid_0's multi_logloss: 1.71657
# [505]	valid_0's multi_logloss: 1.71653
# [506]	valid_0's multi_logloss: 1.7165
# [507]	valid_0's multi_logloss: 1.71647
# [508]	valid_0's multi_logloss: 1.71645
# [509]	valid_0's multi_logloss: 1.71643
# [510]	valid_0's multi_logloss: 1.71639
# [511]	valid_0's multi_logloss: 1.71639
# [512]	valid_0's multi_logloss: 1.71638
# [513]	valid_0's multi_logloss: 1.71635
# [514]	valid_0's multi_logloss: 1.71631
# [515]	valid_0's multi_logloss: 1.71627
# [516]	valid_0's multi_logloss: 1.71625
# [517]	valid_0's multi_logloss: 1.71621
# [518]	valid_0's multi_logloss: 1.71619
# [519]	valid_0's multi_logloss: 1.71616
# [520]	valid_0's multi_logloss: 1.71613
# [521]	valid_0's multi_logloss: 1.71611
# [522]	valid_0's multi_logloss: 1.71609
# [523]	valid_0's multi_logloss: 1.71608
# [524]	valid_0's multi_logloss: 1.71605
# [525]	valid_0's multi_logloss: 1.71604
# [526]	valid_0's multi_logloss: 1.716
# [527]	valid_0's multi_logloss: 1.71596
# [528]	valid_0's multi_logloss: 1.71595
# [529]	valid_0's multi_logloss: 1.71594
# [530]	valid_0's multi_logloss: 1.71593
# [531]	valid_0's multi_logloss: 1.71591
# [532]	valid_0's multi_logloss: 1.71588
# [533]	valid_0's multi_logloss: 1.71587
# [534]	valid_0's multi_logloss: 1.71585
# [535]	valid_0's multi_logloss: 1.71582
# [536]	valid_0's multi_logloss: 1.7158
# [537]	valid_0's multi_logloss: 1.71579
# [538]	valid_0's multi_logloss: 1.71576
# [539]	valid_0's multi_logloss: 1.71574
# [540]	valid_0's multi_logloss: 1.71573
# [541]	valid_0's multi_logloss: 1.71571
# [542]	valid_0's multi_logloss: 1.71569
# [543]	valid_0's multi_logloss: 1.71567
# [544]	valid_0's multi_logloss: 1.71566
# [545]	valid_0's multi_logloss: 1.71563
# [546]	valid_0's multi_logloss: 1.71562
# [547]	valid_0's multi_logloss: 1.71561
# [548]	valid_0's multi_logloss: 1.71559
# [549]	valid_0's multi_logloss: 1.71556
# [550]	valid_0's multi_logloss: 1.71555
# [551]	valid_0's multi_logloss: 1.71551
# [552]	valid_0's multi_logloss: 1.71549
# [553]	valid_0's multi_logloss: 1.71546
# [554]	valid_0's multi_logloss: 1.71546
# [555]	valid_0's multi_logloss: 1.71544
# [556]	valid_0's multi_logloss: 1.7154
# [557]	valid_0's multi_logloss: 1.71539
# [558]	valid_0's multi_logloss: 1.71537
# [559]	valid_0's multi_logloss: 1.71535
# [560]	valid_0's multi_logloss: 1.71532
# [561]	valid_0's multi_logloss: 1.71531
# [562]	valid_0's multi_logloss: 1.71527
# [563]	valid_0's multi_logloss: 1.71526
# [564]	valid_0's multi_logloss: 1.71524
# [565]	valid_0's multi_logloss: 1.71524
# [566]	valid_0's multi_logloss: 1.71522
# [567]	valid_0's multi_logloss: 1.7152
# [568]	valid_0's multi_logloss: 1.71518
# [569]	valid_0's multi_logloss: 1.71517
# [570]	valid_0's multi_logloss: 1.71516
# [571]	valid_0's multi_logloss: 1.71514
# [572]	valid_0's multi_logloss: 1.71512
# [573]	valid_0's multi_logloss: 1.7151
# [574]	valid_0's multi_logloss: 1.71508
# [575]	valid_0's multi_logloss: 1.71504
# [576]	valid_0's multi_logloss: 1.71502
# [577]	valid_0's multi_logloss: 1.71501
# [578]	valid_0's multi_logloss: 1.71499
# [579]	valid_0's multi_logloss: 1.71494
# [580]	valid_0's multi_logloss: 1.71492
# [581]	valid_0's multi_logloss: 1.71489
# [582]	valid_0's multi_logloss: 1.71487
# [583]	valid_0's multi_logloss: 1.71486
# [584]	valid_0's multi_logloss: 1.71486
# [585]	valid_0's multi_logloss: 1.71485
# [586]	valid_0's multi_logloss: 1.71481
# [587]	valid_0's multi_logloss: 1.71481
# [588]	valid_0's multi_logloss: 1.71479
# [589]	valid_0's multi_logloss: 1.71477
# [590]	valid_0's multi_logloss: 1.71474
# [591]	valid_0's multi_logloss: 1.7147
# [592]	valid_0's multi_logloss: 1.71467
# [593]	valid_0's multi_logloss: 1.71465
# [594]	valid_0's multi_logloss: 1.71464
# [595]	valid_0's multi_logloss: 1.71462
# [596]	valid_0's multi_logloss: 1.7146
# [597]	valid_0's multi_logloss: 1.7146
# [598]	valid_0's multi_logloss: 1.71457
# [599]	valid_0's multi_logloss: 1.71455
# [600]	valid_0's multi_logloss: 1.71451
# [601]	valid_0's multi_logloss: 1.71449
# [602]	valid_0's multi_logloss: 1.71449
# [603]	valid_0's multi_logloss: 1.71446
# [604]	valid_0's multi_logloss: 1.71444
# [605]	valid_0's multi_logloss: 1.71443
# [606]	valid_0's multi_logloss: 1.71442
# [607]	valid_0's multi_logloss: 1.71439
# [608]	valid_0's multi_logloss: 1.71438
# [609]	valid_0's multi_logloss: 1.71436
# [610]	valid_0's multi_logloss: 1.71433
# [611]	valid_0's multi_logloss: 1.71433
# [612]	valid_0's multi_logloss: 1.71429
# [613]	valid_0's multi_logloss: 1.71427
# [614]	valid_0's multi_logloss: 1.71424
# [615]	valid_0's multi_logloss: 1.71422
# [616]	valid_0's multi_logloss: 1.7142
# [617]	valid_0's multi_logloss: 1.71417
# [618]	valid_0's multi_logloss: 1.71414
# [619]	valid_0's multi_logloss: 1.71412
# [620]	valid_0's multi_logloss: 1.7141
# [621]	valid_0's multi_logloss: 1.71408
# [622]	valid_0's multi_logloss: 1.71406
# [623]	valid_0's multi_logloss: 1.71402
# [624]	valid_0's multi_logloss: 1.71402
# [625]	valid_0's multi_logloss: 1.71399
# [626]	valid_0's multi_logloss: 1.714
# [627]	valid_0's multi_logloss: 1.71398
# [628]	valid_0's multi_logloss: 1.71395
# [629]	valid_0's multi_logloss: 1.71392
# [630]	valid_0's multi_logloss: 1.7139
# [631]	valid_0's multi_logloss: 1.71388
# [632]	valid_0's multi_logloss: 1.71385
# [633]	valid_0's multi_logloss: 1.71383
# [634]	valid_0's multi_logloss: 1.71382
# [635]	valid_0's multi_logloss: 1.71379
# [636]	valid_0's multi_logloss: 1.71378
# [637]	valid_0's multi_logloss: 1.71378
# [638]	valid_0's multi_logloss: 1.71377
# [639]	valid_0's multi_logloss: 1.71375
# [640]	valid_0's multi_logloss: 1.71373
# [641]	valid_0's multi_logloss: 1.7137
# [642]	valid_0's multi_logloss: 1.7137
# [643]	valid_0's multi_logloss: 1.71368
# [644]	valid_0's multi_logloss: 1.71365
# [645]	valid_0's multi_logloss: 1.71361
# [646]	valid_0's multi_logloss: 1.71357
# [647]	valid_0's multi_logloss: 1.71356
# [648]	valid_0's multi_logloss: 1.71355
# [649]	valid_0's multi_logloss: 1.71353
# [650]	valid_0's multi_logloss: 1.71351
# [651]	valid_0's multi_logloss: 1.7135
# [652]	valid_0's multi_logloss: 1.71347
# [653]	valid_0's multi_logloss: 1.71344
# [654]	valid_0's multi_logloss: 1.71343
# [655]	valid_0's multi_logloss: 1.71342
# [656]	valid_0's multi_logloss: 1.7134
# [657]	valid_0's multi_logloss: 1.71337
# [658]	valid_0's multi_logloss: 1.71338
# [659]	valid_0's multi_logloss: 1.71337
# [660]	valid_0's multi_logloss: 1.71336
# [661]	valid_0's multi_logloss: 1.71334
# [662]	valid_0's multi_logloss: 1.71332
# [663]	valid_0's multi_logloss: 1.71332
# [664]	valid_0's multi_logloss: 1.71333
# [665]	valid_0's multi_logloss: 1.71331
# [666]	valid_0's multi_logloss: 1.71329
# [667]	valid_0's multi_logloss: 1.71329
# [668]	valid_0's multi_logloss: 1.71327
# [669]	valid_0's multi_logloss: 1.71324
# [670]	valid_0's multi_logloss: 1.71323
# [671]	valid_0's multi_logloss: 1.71321
# [672]	valid_0's multi_logloss: 1.7132
# [673]	valid_0's multi_logloss: 1.71317
# [674]	valid_0's multi_logloss: 1.71315
# [675]	valid_0's multi_logloss: 1.71314
# [676]	valid_0's multi_logloss: 1.71312
# [677]	valid_0's multi_logloss: 1.7131
# [678]	valid_0's multi_logloss: 1.71309
# [679]	valid_0's multi_logloss: 1.71306
# [680]	valid_0's multi_logloss: 1.71304
# [681]	valid_0's multi_logloss: 1.71301
# [682]	valid_0's multi_logloss: 1.71298
# [683]	valid_0's multi_logloss: 1.71298
# [684]	valid_0's multi_logloss: 1.71297
# [685]	valid_0's multi_logloss: 1.71295
# [686]	valid_0's multi_logloss: 1.71294
# [687]	valid_0's multi_logloss: 1.71294
# [688]	valid_0's multi_logloss: 1.71293
# [689]	valid_0's multi_logloss: 1.7129
# [690]	valid_0's multi_logloss: 1.71289
# [691]	valid_0's multi_logloss: 1.71288
# [692]	valid_0's multi_logloss: 1.71288
# [693]	valid_0's multi_logloss: 1.71286
# [694]	valid_0's multi_logloss: 1.71284
# [695]	valid_0's multi_logloss: 1.71283
# [696]	valid_0's multi_logloss: 1.7128
# [697]	valid_0's multi_logloss: 1.7128
# [698]	valid_0's multi_logloss: 1.71277
# [699]	valid_0's multi_logloss: 1.71276
# [700]	valid_0's multi_logloss: 1.71274
# [701]	valid_0's multi_logloss: 1.71273
# [702]	valid_0's multi_logloss: 1.71271
# [703]	valid_0's multi_logloss: 1.71269
# [704]	valid_0's multi_logloss: 1.71267
# [705]	valid_0's multi_logloss: 1.71266
# [706]	valid_0's multi_logloss: 1.71261
# [707]	valid_0's multi_logloss: 1.71261
# [708]	valid_0's multi_logloss: 1.7126
# [709]	valid_0's multi_logloss: 1.71259
# [710]	valid_0's multi_logloss: 1.71255
# [711]	valid_0's multi_logloss: 1.71252
# [712]	valid_0's multi_logloss: 1.7125
# [713]	valid_0's multi_logloss: 1.7125
# [714]	valid_0's multi_logloss: 1.71247
# [715]	valid_0's multi_logloss: 1.71245
# [716]	valid_0's multi_logloss: 1.71242
# [717]	valid_0's multi_logloss: 1.7124
# [718]	valid_0's multi_logloss: 1.71236
# [719]	valid_0's multi_logloss: 1.71235
# [720]	valid_0's multi_logloss: 1.71236
# [721]	valid_0's multi_logloss: 1.71234
# [722]	valid_0's multi_logloss: 1.71232
# [723]	valid_0's multi_logloss: 1.71228
# [724]	valid_0's multi_logloss: 1.71227
# [725]	valid_0's multi_logloss: 1.71227
# [726]	valid_0's multi_logloss: 1.71226
# [727]	valid_0's multi_logloss: 1.71225
# [728]	valid_0's multi_logloss: 1.71225
# [729]	valid_0's multi_logloss: 1.71223
# [730]	valid_0's multi_logloss: 1.71221
# [731]	valid_0's multi_logloss: 1.71221
# [732]	valid_0's multi_logloss: 1.71219
# [733]	valid_0's multi_logloss: 1.71218
# [734]	valid_0's multi_logloss: 1.71219
# [735]	valid_0's multi_logloss: 1.71216
# [736]	valid_0's multi_logloss: 1.71214
# [737]	valid_0's multi_logloss: 1.71214
# [738]	valid_0's multi_logloss: 1.71214
# [739]	valid_0's multi_logloss: 1.71213
# [740]	valid_0's multi_logloss: 1.71212
# [741]	valid_0's multi_logloss: 1.71209
# [742]	valid_0's multi_logloss: 1.71208
# [743]	valid_0's multi_logloss: 1.71207
# [744]	valid_0's multi_logloss: 1.71207
# [745]	valid_0's multi_logloss: 1.71207
# [746]	valid_0's multi_logloss: 1.71204
# [747]	valid_0's multi_logloss: 1.71202
# [748]	valid_0's multi_logloss: 1.71202
# [749]	valid_0's multi_logloss: 1.712
# [750]	valid_0's multi_logloss: 1.71198
# [751]	valid_0's multi_logloss: 1.71197
# [752]	valid_0's multi_logloss: 1.71195
# [753]	valid_0's multi_logloss: 1.71196
# [754]	valid_0's multi_logloss: 1.71195
# [755]	valid_0's multi_logloss: 1.71192
# [756]	valid_0's multi_logloss: 1.71192
# [757]	valid_0's multi_logloss: 1.71189
# [758]	valid_0's multi_logloss: 1.71186
# [759]	valid_0's multi_logloss: 1.71186
# [760]	valid_0's multi_logloss: 1.71183
# [761]	valid_0's multi_logloss: 1.71182
# [762]	valid_0's multi_logloss: 1.7118
# [763]	valid_0's multi_logloss: 1.71178
# [764]	valid_0's multi_logloss: 1.71177
# [765]	valid_0's multi_logloss: 1.71177
# [766]	valid_0's multi_logloss: 1.71175
# [767]	valid_0's multi_logloss: 1.71171
# [768]	valid_0's multi_logloss: 1.71169
# [769]	valid_0's multi_logloss: 1.71166
# [770]	valid_0's multi_logloss: 1.71165
# [771]	valid_0's multi_logloss: 1.71164
# [772]	valid_0's multi_logloss: 1.71161
# [773]	valid_0's multi_logloss: 1.71161
# [774]	valid_0's multi_logloss: 1.7116
# [775]	valid_0's multi_logloss: 1.71158
# [776]	valid_0's multi_logloss: 1.71156
# [777]	valid_0's multi_logloss: 1.71155
# [778]	valid_0's multi_logloss: 1.71154
# [779]	valid_0's multi_logloss: 1.71153
# [780]	valid_0's multi_logloss: 1.71153
# [781]	valid_0's multi_logloss: 1.71153
# [782]	valid_0's multi_logloss: 1.71153
# [783]	valid_0's multi_logloss: 1.71153
# [784]	valid_0's multi_logloss: 1.7115
# [785]	valid_0's multi_logloss: 1.7115
# [786]	valid_0's multi_logloss: 1.71149
# [787]	valid_0's multi_logloss: 1.71146
# [788]	valid_0's multi_logloss: 1.71146
# [789]	valid_0's multi_logloss: 1.71146
# [790]	valid_0's multi_logloss: 1.71144
# [791]	valid_0's multi_logloss: 1.71143
# [792]	valid_0's multi_logloss: 1.71141
# [793]	valid_0's multi_logloss: 1.71141
# [794]	valid_0's multi_logloss: 1.7114
# [795]	valid_0's multi_logloss: 1.7114
# [796]	valid_0's multi_logloss: 1.7114
# [797]	valid_0's multi_logloss: 1.71139
# [798]	valid_0's multi_logloss: 1.71139
# [799]	valid_0's multi_logloss: 1.71137
# [800]	valid_0's multi_logloss: 1.71136
# [801]	valid_0's multi_logloss: 1.71134
# [802]	valid_0's multi_logloss: 1.71133
# [803]	valid_0's multi_logloss: 1.71133
# [804]	valid_0's multi_logloss: 1.71131
# [805]	valid_0's multi_logloss: 1.7113
# [806]	valid_0's multi_logloss: 1.71128
# [807]	valid_0's multi_logloss: 1.71127
# [808]	valid_0's multi_logloss: 1.71127
# [809]	valid_0's multi_logloss: 1.71127
# [810]	valid_0's multi_logloss: 1.71125
# [811]	valid_0's multi_logloss: 1.71125
# [812]	valid_0's multi_logloss: 1.71124
# [813]	valid_0's multi_logloss: 1.71122
# [814]	valid_0's multi_logloss: 1.71122
# [815]	valid_0's multi_logloss: 1.71119
# [816]	valid_0's multi_logloss: 1.71118
# [817]	valid_0's multi_logloss: 1.71118
# [818]	valid_0's multi_logloss: 1.71116
# [819]	valid_0's multi_logloss: 1.71115
# [820]	valid_0's multi_logloss: 1.71112
# [821]	valid_0's multi_logloss: 1.71111
# [822]	valid_0's multi_logloss: 1.71111
# [823]	valid_0's multi_logloss: 1.71111
# [824]	valid_0's multi_logloss: 1.71109
# [825]	valid_0's multi_logloss: 1.71109
# [826]	valid_0's multi_logloss: 1.71108
# [827]	valid_0's multi_logloss: 1.71109
# [828]	valid_0's multi_logloss: 1.71111
# [829]	valid_0's multi_logloss: 1.71111
# [830]	valid_0's multi_logloss: 1.71109
# [831]	valid_0's multi_logloss: 1.71107
# [832]	valid_0's multi_logloss: 1.71104
# [833]	valid_0's multi_logloss: 1.71103
# [834]	valid_0's multi_logloss: 1.71104
# [835]	valid_0's multi_logloss: 1.71102
# [836]	valid_0's multi_logloss: 1.711
# [837]	valid_0's multi_logloss: 1.711
# [838]	valid_0's multi_logloss: 1.711
# [839]	valid_0's multi_logloss: 1.711
# [840]	valid_0's multi_logloss: 1.71099
# [841]	valid_0's multi_logloss: 1.71099
# [842]	valid_0's multi_logloss: 1.71099
# [843]	valid_0's multi_logloss: 1.71096
# [844]	valid_0's multi_logloss: 1.71096
# [845]	valid_0's multi_logloss: 1.71095
# [846]	valid_0's multi_logloss: 1.71093
# [847]	valid_0's multi_logloss: 1.71092
# [848]	valid_0's multi_logloss: 1.71088
# [849]	valid_0's multi_logloss: 1.71087
# [850]	valid_0's multi_logloss: 1.71089
# [851]	valid_0's multi_logloss: 1.71087
# [852]	valid_0's multi_logloss: 1.71086
# [853]	valid_0's multi_logloss: 1.71084
# [854]	valid_0's multi_logloss: 1.71082
# [855]	valid_0's multi_logloss: 1.71082
# [856]	valid_0's multi_logloss: 1.7108
# [857]	valid_0's multi_logloss: 1.7108
# [858]	valid_0's multi_logloss: 1.71078
# [859]	valid_0's multi_logloss: 1.71077
# [860]	valid_0's multi_logloss: 1.71076
# [861]	valid_0's multi_logloss: 1.71078
# [862]	valid_0's multi_logloss: 1.71074
# [863]	valid_0's multi_logloss: 1.71072
# [864]	valid_0's multi_logloss: 1.71071
# [865]	valid_0's multi_logloss: 1.7107
# [866]	valid_0's multi_logloss: 1.71068
# [867]	valid_0's multi_logloss: 1.71067
# [868]	valid_0's multi_logloss: 1.71063
# [869]	valid_0's multi_logloss: 1.71064
# [870]	valid_0's multi_logloss: 1.71063
# [871]	valid_0's multi_logloss: 1.71062
# [872]	valid_0's multi_logloss: 1.71059
# [873]	valid_0's multi_logloss: 1.71054
# [874]	valid_0's multi_logloss: 1.71053
# [875]	valid_0's multi_logloss: 1.71053
# [876]	valid_0's multi_logloss: 1.71053
# [877]	valid_0's multi_logloss: 1.71049
# [878]	valid_0's multi_logloss: 1.71047
# [879]	valid_0's multi_logloss: 1.71046
# [880]	valid_0's multi_logloss: 1.71045
# [881]	valid_0's multi_logloss: 1.71044
# [882]	valid_0's multi_logloss: 1.71043
# [883]	valid_0's multi_logloss: 1.71043
# [884]	valid_0's multi_logloss: 1.71041
# [885]	valid_0's multi_logloss: 1.71039
# [886]	valid_0's multi_logloss: 1.71036
# [887]	valid_0's multi_logloss: 1.71036
# [888]	valid_0's multi_logloss: 1.71034
# [889]	valid_0's multi_logloss: 1.71033
# [890]	valid_0's multi_logloss: 1.71033
# [891]	valid_0's multi_logloss: 1.71031
# [892]	valid_0's multi_logloss: 1.71029
# [893]	valid_0's multi_logloss: 1.71027
# [894]	valid_0's multi_logloss: 1.71027
# [895]	valid_0's multi_logloss: 1.71025
# [896]	valid_0's multi_logloss: 1.71023
# [897]	valid_0's multi_logloss: 1.71021
# [898]	valid_0's multi_logloss: 1.71021
# [899]	valid_0's multi_logloss: 1.71021
# [900]	valid_0's multi_logloss: 1.71022
# [901]	valid_0's multi_logloss: 1.71021
# [902]	valid_0's multi_logloss: 1.71019
# [903]	valid_0's multi_logloss: 1.71017
# [904]	valid_0's multi_logloss: 1.71017
# [905]	valid_0's multi_logloss: 1.71015
# [906]	valid_0's multi_logloss: 1.71014
# [907]	valid_0's multi_logloss: 1.71013
# [908]	valid_0's multi_logloss: 1.7101
# [909]	valid_0's multi_logloss: 1.7101
# [910]	valid_0's multi_logloss: 1.71007
# [911]	valid_0's multi_logloss: 1.71007
# [912]	valid_0's multi_logloss: 1.71005
# [913]	valid_0's multi_logloss: 1.71003
# [914]	valid_0's multi_logloss: 1.71003
# [915]	valid_0's multi_logloss: 1.71005
# [916]	valid_0's multi_logloss: 1.71005
# [917]	valid_0's multi_logloss: 1.71003
# [918]	valid_0's multi_logloss: 1.71001
# [919]	valid_0's multi_logloss: 1.71
# [920]	valid_0's multi_logloss: 1.70999
# [921]	valid_0's multi_logloss: 1.70997
# [922]	valid_0's multi_logloss: 1.70995
# [923]	valid_0's multi_logloss: 1.70994
# [924]	valid_0's multi_logloss: 1.70993
# [925]	valid_0's multi_logloss: 1.70992
# [926]	valid_0's multi_logloss: 1.70992
# [927]	valid_0's multi_logloss: 1.70991
# [928]	valid_0's multi_logloss: 1.70989
# [929]	valid_0's multi_logloss: 1.70988
# [930]	valid_0's multi_logloss: 1.70986
# [931]	valid_0's multi_logloss: 1.70985
# [932]	valid_0's multi_logloss: 1.70983
# [933]	valid_0's multi_logloss: 1.70983
# [934]	valid_0's multi_logloss: 1.70983
# [935]	valid_0's multi_logloss: 1.70981
# [936]	valid_0's multi_logloss: 1.70981
# [937]	valid_0's multi_logloss: 1.7098
# [938]	valid_0's multi_logloss: 1.7098
# [939]	valid_0's multi_logloss: 1.7098
# [940]	valid_0's multi_logloss: 1.70981
# [941]	valid_0's multi_logloss: 1.70982
# [942]	valid_0's multi_logloss: 1.70981
# [943]	valid_0's multi_logloss: 1.7098
# [944]	valid_0's multi_logloss: 1.70979
# [945]	valid_0's multi_logloss: 1.70978
# [946]	valid_0's multi_logloss: 1.70976
# [947]	valid_0's multi_logloss: 1.70974
# [948]	valid_0's multi_logloss: 1.70973
# [949]	valid_0's multi_logloss: 1.70974
# [950]	valid_0's multi_logloss: 1.70973
# [951]	valid_0's multi_logloss: 1.70971
# [952]	valid_0's multi_logloss: 1.7097
# [953]	valid_0's multi_logloss: 1.7097
# [954]	valid_0's multi_logloss: 1.70969
# [955]	valid_0's multi_logloss: 1.7097
# [956]	valid_0's multi_logloss: 1.70969
# [957]	valid_0's multi_logloss: 1.70968
# [958]	valid_0's multi_logloss: 1.7097
# [959]	valid_0's multi_logloss: 1.70969
# [960]	valid_0's multi_logloss: 1.70968
# [961]	valid_0's multi_logloss: 1.70969
# [962]	valid_0's multi_logloss: 1.70968
# [963]	valid_0's multi_logloss: 1.70967
# [964]	valid_0's multi_logloss: 1.70967
# [965]	valid_0's multi_logloss: 1.70966
# [966]	valid_0's multi_logloss: 1.70966
# [967]	valid_0's multi_logloss: 1.70964
# [968]	valid_0's multi_logloss: 1.70965
# [969]	valid_0's multi_logloss: 1.70964
# [970]	valid_0's multi_logloss: 1.70964
# [971]	valid_0's multi_logloss: 1.70964
# [972]	valid_0's multi_logloss: 1.70963
# [973]	valid_0's multi_logloss: 1.7096
# [974]	valid_0's multi_logloss: 1.7096
# [975]	valid_0's multi_logloss: 1.7096
# [976]	valid_0's multi_logloss: 1.7096
# [977]	valid_0's multi_logloss: 1.7096
# [978]	valid_0's multi_logloss: 1.70958
# [979]	valid_0's multi_logloss: 1.70958
# [980]	valid_0's multi_logloss: 1.70958
# [981]	valid_0's multi_logloss: 1.7096
# [982]	valid_0's multi_logloss: 1.7096
# [983]	valid_0's multi_logloss: 1.70959
# [984]	valid_0's multi_logloss: 1.7096
# [985]	valid_0's multi_logloss: 1.70959
# [986]	valid_0's multi_logloss: 1.70959
# [987]	valid_0's multi_logloss: 1.70958
# [988]	valid_0's multi_logloss: 1.70956
# [989]	valid_0's multi_logloss: 1.70954
# [990]	valid_0's multi_logloss: 1.70953
# [991]	valid_0's multi_logloss: 1.70951
# [992]	valid_0's multi_logloss: 1.70951
# [993]	valid_0's multi_logloss: 1.70951
# [994]	valid_0's multi_logloss: 1.70948
# [995]	valid_0's multi_logloss: 1.70947
# [996]	valid_0's multi_logloss: 1.70947
# [997]	valid_0's multi_logloss: 1.70946
# [998]	valid_0's multi_logloss: 1.70946
# [999]	valid_0's multi_logloss: 1.70946
# [1000]	valid_0's multi_logloss: 1.70946
# Did not meet early stopping. Best iteration is:
# [998]	valid_0's multi_logloss: 1.70946

# %% [markdown]
# ### Prediction

# %%
predictions = []
import numpy as np
for x in gbm.predict(x_train):
    predictions.append(np.argmax(x))

y_train_pred = np.array(predictions).reshape(-1)
y_train_true = y_train

from sklearn.metrics import confusion_matrix
print("== Train Obs ==")
print('{:,} obs' .format(len(x_train)), end="\n\n")
print("== Train Error Matrix ==")
print(confusion_matrix(y_train_true, y_train_pred), end="\n\n")
print("== Train Accuracy ==")
acc = (2039+1441+1335+1523+4324+85384+85759+1497+895+901+1054+1773) / len(y_train)
print("train accuracy : {:.2f}%" .format(acc * 100))
adj_acc = (50 + 8 + 41 + 83 + 675 + 86279 + 38899 + 96 + 16 + 9 + 8 + 44) / 422693
print("test adjust accuracy : {:.2f}%" .format((acc - adj_acc) * 100))
# Out:
# == Train Obs ==
# 422,693 obs
#
# == Train Error Matrix ==
# [[ 2039     3     7     5    46   708   392     0     0     0     0     5]
#  [   22  1441     4     5    43   993   487     1     0     0     0     6]
#  [   38     7  1335    43   196  3886  1752     5     3     0     0    17]
#  [   54    10    23  1523   497 11540  5473    26     6     2     0    28]
#  [   68    14    20    69  4324 31398 16210    59    10     1     0    33]
#  [   54    11    24    70   559 85384 39976    67    13     5     4    41]
#  [   43     8    19    75   575 44950 85759    85    17     7     0    64]
#  [   40     6    21    48   396 22395 18992  1497    23     6     1    40]
#  [   32     6    13    26   179  9146  7021    32   895     7     5    19]
#  [   16     2     6     5   108  3968  2908    18     6   901     2    16]
#  [    6     2     1     3    33  1744  1133     7     0     3  1054    16]
#  [   14     0     3    15    96  3124  2157    12     2     2     4  1773]]
#
# == Train Accuracy ==
# train accuracy : 44.46%
# test adjust accuracy : 14.60%

# %%
predictions = []
for x in gbm.predict(x_valid):
    predictions.append(np.argmax(x))

y_valid_pred = np.array(predictions).reshape(-1)
y_valid_true = y_valid

from sklearn.metrics import confusion_matrix
print("== Valid Obs ==")
print('{:,} obs' .format(len(x_valid)), end="\n\n")
print("== Valid Error Matrix ==")
print(confusion_matrix(y_valid_true, y_valid_pred), end="\n\n")
print("== Valid Accuracy ==")
acc = (111 + 15 + 33 + 79 + 518 + 17318 + 17810 + 106 + 22 + 7 + 5 + 95) / len(y_valid)
print("valid accuracy : {:.2f}%" .format(acc * 100))
adj_acc = (228 + 12 + 26 + 57 + 420 + 17796 + 12970 + 66 + 14 + 4 + 7 + 38) / 105674
print("test adjust accuracy : {:.2f}%" .format((acc - adj_acc) * 100))
# Out:
# == Valid Obs ==
# 105,674 obs
#
# == Valid Error Matrix ==
# [[  108     8    18    20    44   390   187     3     1     0     2     8]
#  [   22     7    13    15    57   471   210     2     2     2     0     6]
#  [   22    13    31    28    73  1073   506     4     2     3     1     8]
#  [   35     6    26    58   216  2968  1397    13     4     2     2    15]
#  [   36    11    17    70   374  8415  4270    27    10     7     5    26]
#  [   26    10    11    47   345 17828 13081    42     8     4     5    31]
#  [   27     8    15    28   245 14671 17718    83    21     6     4    38]
#  [   13     7    13    21   146  5687  5005    49    19     6     8    32]
#  [    5     1     5    14    82  2214  1881    17     7     6     1    15]
#  [    3     3     3     8    37  1080   746    12     7     4     4     8]
#  [    2     1     4     2    24   579   403     8     4     2     2     8]
#  [   16     6     3     9    47   908   711    12     4     0     6    72]]
#
# == Valid Accuracy ==
# valid accuracy : 34.18%
# test adjust accuracy : 4.24%

# %%
predictions = []
for x in gbm.predict(x_test):
    predictions.append(np.argmax(x))

y_test_pred = np.array(predictions).reshape(-1)
y_test_true = y_test

from sklearn.metrics import confusion_matrix
print("== Test Obs ==")
print('{:,} obs' .format(len(x_test)), end="\n\n")
print("== Test Error Matrix ==")
print(confusion_matrix(y_test_true, y_test_pred), end="\n\n")
print("== Test Accuracy ==")
M = confusion_matrix(y_test_true, y_test_pred)
acc = (M[0,0]+M[1,1]+M[2,2]+M[3,3]+M[4,4]+M[5,5]+M[6,6]+M[7,7]+M[8,8]+M[9,9]+M[10,10]+M[11,11]) / len(y_test)
print("Test Accuracy : {:.2f}%" .format(acc * 100))
adj_acc = (M[5,0]+M[5,1]+M[5,2]+M[5,3]+M[5,4]+M[5,5]+M[5,6]+M[5,7]+M[5,8]+M[5,9]+M[5,10]+M[5,11]) / 58708
print("Test Adjust Accuracy : {:.2f}%" .format((acc - adj_acc) * 100))

# 히트맵
heatmap =pd.DataFrame(confusion_matrix(y_test_true, y_test_pred),
                      columns=['-INF ~ -15', '-15 ~ -12', '-12 ~ -9', '-9 ~ -6', '-6 ~ -3', '-3 ~ 0',\
                               '0 ~ 3', '3 ~ 6', '6 ~ 9', '9 ~ 12', '12 ~ 15', '15 ~ +INF'],
                      index=['-INF ~ -15', '-15 ~ -12', '-12 ~ -9', '-9 ~ -6', '-6 ~ -3', '-3 ~ 0',\
                               '0 ~ 3', '3 ~ 6', '6 ~ 9', '9 ~ 12', '12 ~ 15', '15 ~ +INF'])
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(12,10))
map = sns.heatmap(heatmap, annot=True, fmt="d", linewidths=.5, ax=ax, cmap='coolwarm')
map.set_ylim(12,0)
plt.show()
# Out:
# == Test Obs ==
# 58,708 obs
#
# == Test Error Matrix ==
# [[  63   15    8   14   23  216  130    1    0    0    0    4]
#  [  17    6   10    7   34  238  124    2    1    1    0    4]
#  [  11    9   16   20   48  622  287    1    0    0    1   10]
#  [  22    7   16   33  101 1676  813    9    2    1    3   10]
#  [  20    7   10   46  173 4754 2354   13    4    6    1    6]
#  [  21    2   12   24  167 9899 7312   20    2    4    2   19]
#  [  17    4    7   27  158 8001 9742   30    8    6    3   14]
#  [  14    3    3   12   75 3155 2846   30    6    4    1   13]
#  [   2    4    1    5   36 1250  973    7    5    4    4    6]
#  [   6    0    2    3   26  584  492    8    3    9    2    6]
#  [   6    1    2    5    9  288  202    2    1    0    3    6]
#  [   6    2    0    7   32  531  419    9    3    1    2   40]]
#
# == Test Accuracy ==
# Test Accuracy : 34.10%
# Test Adjust Accuracy : 4.32%

# %% [markdown]
# ### Test 상승, 하락, 2 Class로만 분류한 경우

# %%
# 2x2 행렬 계산
M11 = 0
for i in range(0,6) : 
    for j in range(0,6) : 
        M11 += confusion_matrix(y_test_true, y_test_pred)[i,j]
M12 = 0
for i in range(6,12) : 
    for j in range(0,6) : 
        M12 += confusion_matrix(y_test_true, y_test_pred)[i,j]
M21 = 0
for i in range(0,6) : 
    for j in range(6,12) : 
        M21 += confusion_matrix(y_test_true, y_test_pred)[i,j]
M22 = 0
for i in range(6,12) : 
    for j in range(6,12) : 
        M22 += confusion_matrix(y_test_true, y_test_pred)[i,j]

        
# 계산된 2x2 행렬
Class3 = np.array([[M11, M12],
                   [M21, M22]])

# 결과 출력
print("== Test Obs ==")
print('{:,} obs' .format(len(x_test)), end="\n\n")
print("== Up and Down ==")
print(Class3, end="\n\n")
print("== Accuracy ==")
acc = (M11 + M22) / (M11 + M12 + M21 + M22)
print("Test 3 Class Accuracy = {:.2f}%". format(acc*100))
adj_acc = (M11 + M12) / (M11 + M12 + M21 + M22)
print("Test Adjust Accuracy : {:.2f}%" .format((acc - adj_acc) * 100))

# 히트맵
heatmap =pd.DataFrame(Class3, columns=['Down', 'Up'], index = ['Down', 'Up'])
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(10,6))
map = sns.heatmap(heatmap, annot=True, fmt="d", linewidths=.5, ax=ax, cmap='coolwarm')
map.set_ylim(2,0)
plt.show()
# Out:
# == Test Obs ==
# 58,708 obs
#
# == Up and Down ==
# [[18367 14284]
#  [11147 14910]]
#
# == Accuracy ==
# Test 3 Class Accuracy = 56.68%
# Test Adjust Accuracy : 1.07%
