# %% [markdown]
# # 1. Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import os
import seaborn as sns

# %% [markdown]
# # 2. SK HYNIX

# %%
data = pd.read_csv("./data/SKHYNIX.csv")
data = data[data.columns[2:-1]]

# %% [markdown]
# # 3. Date Setting

# %%
data["date"] = pd.to_datetime(data["date"])
data = data.set_index("date")

# %% [markdown]
# # 4. Data head

# %%
data.head(10)
# Out:
#              open   high    low  close  trading_volume  trading_value
# date
# 2017-01-02  44750  46000  44600  45800         1547681    70741238750
# 2017-01-03  46200  47300  46200  47250         2655477   124284065200
# 2017-01-04  47000  47150  46200  46500         2722599   127044173970
# 2017-01-05  47000  47500  46850  46950         2377163   112240246450
# 2017-01-06  47700  48450  47600  48000         3166843   152264047270
# 2017-01-09  48500  49750  48200  49550         3871999   191236382800
# 2017-01-10  49850  50200  49200  49750         2561968   127213145450
# 2017-01-11  50000  51900  50000  51600         4360058   223583642680
# 2017-01-12  51600  51600  50400  50600         5060622   256710131000
# 2017-01-13  49850  50700  49850  50300         4219771   211612764000

# %% [markdown]
# #  5. Train Test Split

# %%
split_date = pd.Timestamp("2019-09-30")
train = data.loc[:split_date, ["open", "high", "low", "close"]]
test = data.loc[split_date:, ["open", "high", "low", "close"]]

# %% [markdown]
# # 6. Train Test Visualization

# %%
ax = train.plot(figsize=(16,8), color='dodgerblue', linewidth=2)
test.plot(ax=ax, color='peru', linewidth=3)
plt.legend(['train', 'test'])
plt.show()

# %% [markdown]
# # 7.Data MinMaxSacling

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
train_sc = sc.fit_transform(train)
test_sc = sc.transform(test)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %% [markdown]
# # 8. Transform to Pandas DataFrame

# %%
train_sc_df = pd.DataFrame(train_sc, columns=["open", "high", "low", "close"], index=train.index)
test_sc_df = pd.DataFrame(test_sc, columns=["open", "high", "low", "close"], index=test.index)

# %% [markdown]
# # 9. train_sc_df

# %%
train_sc_df
# Out:
#                 open      high    low     close
# date
# 2017-01-02  0.000000  0.000000  0.000  0.000000
# 2017-01-03  0.028684  0.025145  0.032  0.029293
# 2017-01-04  0.044510  0.022244  0.032  0.014141
# 2017-01-05  0.044510  0.029014  0.045  0.023232
# 2017-01-06  0.058358  0.047389  0.060  0.044444
# ...              ...       ...    ...       ...
# 2019-09-24  0.746785  0.725338  0.736  0.759596
# 2019-09-25  0.740851  0.711799  0.738  0.729293
# 2019-09-26  0.756677  0.725338  0.758  0.757576
# 2019-09-27  0.701286  0.686654  0.710  0.719192
# 2019-09-30  0.709199  0.713733  0.716  0.735354
#
# [671 rows x 4 columns]

# %% [markdown]
# # 10. Setting for Sliding Window

# %%
# List
columns = ["open", "high", "low", "close"]

for col in columns : 
    for s in range(5, 17):
        train_sc_df['{} shift_-{}'.format(col,s)] = train_sc_df[col].shift(s)
        test_sc_df['{} shift_-{}'.format(col,s)] = test_sc_df[col].shift(s)
train_sc_df.head(18)
# Out:
#                 open      high    low     close  open shift_-5  open shift_-6  \
# date
# 2017-01-02  0.000000  0.000000  0.000  0.000000            NaN            NaN
# 2017-01-03  0.028684  0.025145  0.032  0.029293            NaN            NaN
# 2017-01-04  0.044510  0.022244  0.032  0.014141            NaN            NaN
# 2017-01-05  0.044510  0.029014  0.045  0.023232            NaN            NaN
# 2017-01-06  0.058358  0.047389  0.060  0.044444            NaN            NaN
# 2017-01-09  0.074184  0.072534  0.072  0.075758       0.000000            NaN
# 2017-01-10  0.100890  0.081238  0.092  0.079798       0.028684       0.000000
# 2017-01-11  0.103858  0.114120  0.108  0.117172       0.044510       0.028684
# 2017-01-12  0.135509  0.108317  0.116  0.096970       0.044510       0.044510
# 2017-01-13  0.100890  0.090909  0.105  0.090909       0.058358       0.044510
# 2017-01-16  0.105836  0.083172  0.084  0.070707       0.074184       0.058358
# 2017-01-17  0.090010  0.081238  0.093  0.070707       0.100890       0.074184
# 2017-01-18  0.083086  0.065764  0.074  0.061616       0.103858       0.100890
# 2017-01-19  0.094955  0.079304  0.090  0.076768       0.135509       0.103858
# 2017-01-20  0.097923  0.079304  0.091  0.067677       0.100890       0.135509
# 2017-01-23  0.102868  0.096712  0.106  0.101010       0.105836       0.100890
# 2017-01-24  0.129575  0.116054  0.130  0.117172       0.090010       0.105836
# 2017-01-25  0.147379  0.125725  0.140  0.119192       0.083086       0.090010
#
#             open shift_-7  open shift_-8  open shift_-9  open shift_-10  ...  \
# date                                                                     ...
# 2017-01-02            NaN            NaN            NaN             NaN  ...
# 2017-01-03            NaN            NaN            NaN             NaN  ...
# 2017-01-04            NaN            NaN            NaN             NaN  ...
# 2017-01-05            NaN            NaN            NaN             NaN  ...
# 2017-01-06            NaN            NaN            NaN             NaN  ...
# 2017-01-09            NaN            NaN            NaN             NaN  ...
# 2017-01-10            NaN            NaN            NaN             NaN  ...
# 2017-01-11       0.000000            NaN            NaN             NaN  ...
# 2017-01-12       0.028684       0.000000            NaN             NaN  ...
# 2017-01-13       0.044510       0.028684       0.000000             NaN  ...
# 2017-01-16       0.044510       0.044510       0.028684        0.000000  ...
# 2017-01-17       0.058358       0.044510       0.044510        0.028684  ...
# 2017-01-18       0.074184       0.058358       0.044510        0.044510  ...
# 2017-01-19       0.100890       0.074184       0.058358        0.044510  ...
# 2017-01-20       0.103858       0.100890       0.074184        0.058358  ...
# 2017-01-23       0.135509       0.103858       0.100890        0.074184  ...
# 2017-01-24       0.100890       0.135509       0.103858        0.100890  ...
# 2017-01-25       0.105836       0.100890       0.135509        0.103858  ...
#
#             close shift_-7  close shift_-8  close shift_-9  close shift_-10  \
# date
# 2017-01-02             NaN             NaN             NaN              NaN
# 2017-01-03             NaN             NaN             NaN              NaN
# 2017-01-04             NaN             NaN             NaN              NaN
# 2017-01-05             NaN             NaN             NaN              NaN
# 2017-01-06             NaN             NaN             NaN              NaN
# 2017-01-09             NaN             NaN             NaN              NaN
# 2017-01-10             NaN             NaN             NaN              NaN
# 2017-01-11        0.000000             NaN             NaN              NaN
# 2017-01-12        0.029293        0.000000             NaN              NaN
# 2017-01-13        0.014141        0.029293        0.000000              NaN
# 2017-01-16        0.023232        0.014141        0.029293         0.000000
# 2017-01-17        0.044444        0.023232        0.014141         0.029293
# 2017-01-18        0.075758        0.044444        0.023232         0.014141
# 2017-01-19        0.079798        0.075758        0.044444         0.023232
# 2017-01-20        0.117172        0.079798        0.075758         0.044444
# 2017-01-23        0.096970        0.117172        0.079798         0.075758
# 2017-01-24        0.090909        0.096970        0.117172         0.079798
# 2017-01-25        0.070707        0.090909        0.096970         0.117172
#
#             close shift_-11  close shift_-12  close shift_-13  \
# date
# 2017-01-02              NaN              NaN              NaN
# 2017-01-03              NaN              NaN              NaN
# 2017-01-04              NaN              NaN              NaN
# 2017-01-05              NaN              NaN              NaN
# 2017-01-06              NaN              NaN              NaN
# 2017-01-09              NaN              NaN              NaN
# 2017-01-10              NaN              NaN              NaN
# 2017-01-11              NaN              NaN              NaN
# 2017-01-12              NaN              NaN              NaN
# 2017-01-13              NaN              NaN              NaN
# 2017-01-16              NaN              NaN              NaN
# 2017-01-17         0.000000              NaN              NaN
# 2017-01-18         0.029293         0.000000              NaN
# 2017-01-19         0.014141         0.029293         0.000000
# 2017-01-20         0.023232         0.014141         0.029293
# 2017-01-23         0.044444         0.023232         0.014141
# 2017-01-24         0.075758         0.044444         0.023232
# 2017-01-25         0.079798         0.075758         0.044444
#
#             close shift_-14  close shift_-15  close shift_-16
# date
# 2017-01-02              NaN              NaN              NaN
# 2017-01-03              NaN              NaN              NaN
# 2017-01-04              NaN              NaN              NaN
# 2017-01-05              NaN              NaN              NaN
# 2017-01-06              NaN              NaN              NaN
# 2017-01-09              NaN              NaN              NaN
# 2017-01-10              NaN              NaN              NaN
# 2017-01-11              NaN              NaN              NaN
# 2017-01-12              NaN              NaN              NaN
# 2017-01-13              NaN              NaN              NaN
# 2017-01-16              NaN              NaN              NaN
# 2017-01-17              NaN              NaN              NaN
# 2017-01-18              NaN              NaN              NaN
# 2017-01-19              NaN              NaN              NaN
# 2017-01-20         0.000000              NaN              NaN
# 2017-01-23         0.029293         0.000000              NaN
# 2017-01-24         0.014141         0.029293         0.000000
# 2017-01-25         0.023232         0.014141         0.029293
#
# [18 rows x 52 columns]

# %% [markdown]
# # 11. NaN Omit

# %%
X_train = train_sc_df.dropna().drop(["open", "high", "low", "close"], axis=1)
y_train = train_sc_df.dropna()[["open", "high", "low", "close"]]["close"]

# %%
X_test = test_sc_df.dropna().drop(["open", "high", "low", "close"], axis=1)
y_test = test_sc_df.dropna()[["open", "high", "low", "close"]]["close"]

# %% [markdown]
# # 12. Final Train & Test

# %%
X_train.head()
# Out:
#             open shift_-5  open shift_-6  open shift_-7  open shift_-8  \
# date
# 2017-01-24       0.090010       0.105836       0.100890       0.135509
# 2017-01-25       0.083086       0.090010       0.105836       0.100890
# 2017-01-26       0.094955       0.083086       0.090010       0.105836
# 2017-01-31       0.097923       0.094955       0.083086       0.090010
# 2017-02-01       0.102868       0.097923       0.094955       0.083086
#
#             open shift_-9  open shift_-10  open shift_-11  open shift_-12  \
# date
# 2017-01-24       0.103858        0.100890        0.074184        0.058358
# 2017-01-25       0.135509        0.103858        0.100890        0.074184
# 2017-01-26       0.100890        0.135509        0.103858        0.100890
# 2017-01-31       0.105836        0.100890        0.135509        0.103858
# 2017-02-01       0.090010        0.105836        0.100890        0.135509
#
#             open shift_-13  open shift_-14  ...  close shift_-7  \
# date                                        ...
# 2017-01-24        0.044510        0.044510  ...        0.090909
# 2017-01-25        0.058358        0.044510  ...        0.070707
# 2017-01-26        0.074184        0.058358  ...        0.070707
# 2017-01-31        0.100890        0.074184  ...        0.061616
# 2017-02-01        0.103858        0.100890  ...        0.076768
#
#             close shift_-8  close shift_-9  close shift_-10  close shift_-11  \
# date
# 2017-01-24        0.096970        0.117172         0.079798         0.075758
# 2017-01-25        0.090909        0.096970         0.117172         0.079798
# 2017-01-26        0.070707        0.090909         0.096970         0.117172
# 2017-01-31        0.070707        0.070707         0.090909         0.096970
# 2017-02-01        0.061616        0.070707         0.070707         0.090909
#
#             close shift_-12  close shift_-13  close shift_-14  \
# date
# 2017-01-24         0.044444         0.023232         0.014141
# 2017-01-25         0.075758         0.044444         0.023232
# 2017-01-26         0.079798         0.075758         0.044444
# 2017-01-31         0.117172         0.079798         0.075758
# 2017-02-01         0.096970         0.117172         0.079798
#
#             close shift_-15  close shift_-16
# date
# 2017-01-24         0.029293         0.000000
# 2017-01-25         0.014141         0.029293
# 2017-01-26         0.023232         0.014141
# 2017-01-31         0.044444         0.023232
# 2017-02-01         0.075758         0.044444
#
# [5 rows x 48 columns]

# %%
X_train.columns
# Out:
# Index(['open shift_-5', 'open shift_-6', 'open shift_-7', 'open shift_-8',
#        'open shift_-9', 'open shift_-10', 'open shift_-11', 'open shift_-12',
#        'open shift_-13', 'open shift_-14', 'open shift_-15', 'open shift_-16',
#        'high shift_-5', 'high shift_-6', 'high shift_-7', 'high shift_-8',
#        'high shift_-9', 'high shift_-10', 'high shift_-11', 'high shift_-12',
#        'high shift_-13', 'high shift_-14', 'high shift_-15', 'high shift_-16',
#        'low shift_-5', 'low shift_-6', 'low shift_-7', 'low shift_-8',
#        'low shift_-9', 'low shift_-10', 'low shift_-11', 'low shift_-12',
#        'low shift_-13', 'low shift_-14', 'low shift_-15', 'low shift_-16',
#        'close shift_-5', 'close shift_-6', 'close shift_-7', 'close shift_-8',
#        'close shift_-9', 'close shift_-10', 'close shift_-11',
#        'close shift_-12', 'close shift_-13', 'close shift_-14',
#        'close shift_-15', 'close shift_-16'],
#       dtype='object')

# %%
y_train.head()
# Out:
# date
# 2017-01-24    0.117172
# 2017-01-25    0.119192
# 2017-01-26    0.151515
# 2017-01-31    0.159596
# 2017-02-01    0.165657
# Name: close, dtype: float64

# %%
X_test.head()
# Out:
#             open shift_-5  open shift_-6  open shift_-7  open shift_-8  \
# date
# 2019-10-24       0.736894       0.744807       0.711177       0.736894
# 2019-10-25       0.727003       0.736894       0.744807       0.711177
# 2019-10-28       0.653808       0.727003       0.736894       0.744807
# 2019-10-29       0.675569       0.653808       0.727003       0.736894
# 2019-10-30       0.667656       0.675569       0.653808       0.727003
#
#             open shift_-9  open shift_-10  open shift_-11  open shift_-12  \
# date
# 2019-10-24       0.693373        0.675569        0.705242        0.711177
# 2019-10-25       0.736894        0.693373        0.675569        0.705242
# 2019-10-28       0.711177        0.736894        0.693373        0.675569
# 2019-10-29       0.744807        0.711177        0.736894        0.693373
# 2019-10-30       0.736894        0.744807        0.711177        0.736894
#
#             open shift_-13  open shift_-14  ...  close shift_-7  \
# date                                        ...
# 2019-10-24        0.675569        0.728981  ...        0.715152
# 2019-10-25        0.711177        0.675569  ...        0.739394
# 2019-10-28        0.705242        0.711177  ...        0.711111
# 2019-10-29        0.675569        0.705242  ...        0.638384
# 2019-10-30        0.693373        0.675569  ...        0.640404
#
#             close shift_-8  close shift_-9  close shift_-10  close shift_-11  \
# date
# 2019-10-24        0.701010        0.690909         0.670707         0.709091
# 2019-10-25        0.715152        0.701010         0.690909         0.670707
# 2019-10-28        0.739394        0.715152         0.701010         0.690909
# 2019-10-29        0.711111        0.739394         0.715152         0.701010
# 2019-10-30        0.638384        0.711111         0.739394         0.715152
#
#             close shift_-12  close shift_-13  close shift_-14  \
# date
# 2019-10-24         0.696970         0.696970         0.680808
# 2019-10-25         0.709091         0.696970         0.696970
# 2019-10-28         0.670707         0.709091         0.696970
# 2019-10-29         0.690909         0.670707         0.709091
# 2019-10-30         0.701010         0.690909         0.670707
#
#             close shift_-15  close shift_-16
# date
# 2019-10-24         0.731313         0.735354
# 2019-10-25         0.680808         0.731313
# 2019-10-28         0.696970         0.680808
# 2019-10-29         0.696970         0.696970
# 2019-10-30         0.709091         0.696970
#
# [5 rows x 48 columns]

# %%
y_test.head()
# Out:
# date
# 2019-10-24    0.690909
# 2019-10-25    0.749495
# 2019-10-28    0.749495
# 2019-10-29    0.751515
# 2019-10-30    0.721212
# Name: close, dtype: float64

# %% [markdown]
# # 13. ndarray to Tranform

# %%
X_train = X_train.values
X_test = X_test.values
y_train = y_train.values
y_test = y_test.values

# %% [markdown]
# # 14. Final Training Set & Test Set's X

# %%
X_train_t = X_train.reshape(X_train.shape[0], 48, 1)
X_test_t = X_test.reshape(X_test.shape[0], 48, 1)

# %% [markdown]
# # 15. Seed Setting

# %%
from numpy.random import seed
seed(1234)
from tensorflow import set_random_seed
set_random_seed(1234)

# %% [markdown]
# # 16. LSTM Model

# %%
# Library
from keras.layers import LSTM 
from keras.models import Sequential 
from keras.layers import Dense 
import keras.backend as K
from keras.callbacks import EarlyStopping
from keras.layers import Dense, Dropout, Activation

# Sequeatial Model 
K.clear_session() 
model = Sequential()

# 1층
model.add(LSTM(10, input_shape=(48,1))) # (timestep, feature) 
model.add(Dense(1)) # output = 1 

# 결과
model.compile(loss='mean_squared_error', optimizer='adam') 
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 10)                480
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 491
# Trainable params: 491
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 17. Model Fitting

# %%
early_stop = EarlyStopping(monitor='loss', patience=30, verbose=1)
model.fit(X_train_t, y_train, epochs=200, batch_size=30, verbose=1, callbacks=[early_stop])
# Out:
# Epoch 1/1000
#
1000
# 655/655 [==============================] - 1s 930us/step - loss: 0.0050
# Epoch 337/1000
# 655/655 [==============================] - 1s 943us/step - loss: 0.0049
# Epoch 338/1000
# 655/655 [==============================] - 1s 927us/step - loss: 0.0051
# Epoch 339/1000
# 655/655 [==============================] - 1s 939us/step - loss: 0.0049
# Epoch 340/1000
# 655/655 [==============================] - 1s 953us/step - loss: 0.0050
# Epoch 341/1000
# 655/655 [==============================] - 1s 930us/step - loss: 0.0050
# Epoch 342/1000
# 655/655 [==============================] - 1s 923us/step - loss: 0.0050
# Epoch 343/1000
# 655/655 [==============================] - 1s 967us/step - loss: 0.0051
# Epoch 344/1000
# 655/655 [==============================] - 1s 965us/step - loss: 0.0052
# Epoch 345/1000
# 655/655 [==============================] - 1s 936us/step - loss: 0.0050
# Epoch 346/1000
# 655/655 [==============================] - 1s 938us/step - loss: 0.0049
# Epoch 00346: early stopping

# %% [markdown]
# # 18. Train Prediction

# %%
# Pred
y_pred = model.predict(X_train_t)
PRED = pd.DataFrame(y_pred)
PRED.columns = ["PRED"]

# Actual
REAL = pd.DataFrame(y_train)
REAL.columns = ["REAL"]

# Setting
RESULT = pd.concat([REAL,PRED], axis=1)
RESULT["date"] = train.index[16:]

# Set Index
RESULT = RESULT.set_index("date")

# Pred
y_pred = model.predict(X_train_t)
y_pred = y_pred * (np.max(train["close"]) -  np.min(train["close"])) +  np.min(train["close"])
y_pred_df = pd.DataFrame(y_pred, columns=['prediction'], index=train.index[16:])

# True
y_train = y_train * (np.max(train["close"]) -  np.min(train["close"])) +  np.min(train["close"])
y_train_df = pd.DataFrame(y_train, columns=['actual_price'], index=train.index[16:])

# plotting the results
fig = plt.figure(figsize=(16,8))
fig.patch.set_facecolor('xkcd:white')
plt.plot(y_pred_df["prediction"], color = 'blue', label = 'Predicted Stock Price', linewidth = 3)
plt.plot(y_train_df["actual_price"], color = 'red', label = 'Actual Stock Price', linewidth = 3)
plt.title('Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# # 19. Test Prediction

# %%
# Pred
y_pred = model.predict(X_test_t)
PRED = pd.DataFrame(y_pred)
PRED.columns = ["PRED"]

# Actual
REAL = pd.DataFrame(y_test)
REAL.columns = ["REAL"]

RESULT_TEST = pd.concat([REAL,PRED], axis=1)
RESULT_TEST["date"] = test.index[16:]

RESULT_TEST = RESULT_TEST.set_index("date")

y_pred = model.predict(X_test_t)
y_pred = y_pred * (np.max(test["close"]) -  np.min(test["close"])) +  np.min(test["close"])
y_pred_df = pd.DataFrame(y_pred, columns=['prediction'], index=test.index[16:])

y_test = y_test * (np.max(test["close"]) -  np.min(test["close"])) +  np.min(test["close"])
y_test_df = pd.DataFrame(y_test, columns=['actual_price'], index=test.index[16:])

# plotting the results
fig = plt.figure(figsize=(16,8))
fig.patch.set_facecolor('xkcd:white')
plt.plot(y_pred_df["prediction"], color = 'blue', label = 'Predicted Stock Price', linewidth = 3)
plt.plot(y_test_df["actual_price"], color = 'red', label = 'Actual Stock Price', linewidth = 3)
plt.title('Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# # 20. Test RMSE

# %%
forecast_error = y_test.reshape(-1,1) - y_pred
SS, RMSE = 0, 0
for i in forecast_error : 
    SS = SS + i * i
    RMSE = SS / len(forecast_error)
print("Test DataSet's RMSE : {}" .format(float(RMSE**0.5)))
# Out:
# Test DataSet's RMSE : 1695.1478988744657
