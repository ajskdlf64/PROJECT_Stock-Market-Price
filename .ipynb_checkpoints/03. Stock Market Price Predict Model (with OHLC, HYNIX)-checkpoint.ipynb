# %% [markdown]
# # **Library**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import os
import seaborn as sns

# %% [markdown]
# # **하이닉스**

# %%
DATA_2017 = pd.read_excel("./data/2017년 주가 기본 데이터.xlsx")
DATA_2018 = pd.read_excel("./data/2018년 주가 기본 데이터.xlsx")
DATA_2019 = pd.read_excel("./data/2019년 주가 기본 데이터.xlsx")

# 하이닉스
data_2017 = DATA_2017[DATA_2017["code"] == "000660"]
data_2018 = DATA_2018[DATA_2018["code"] == "000660"]
data_2019 = DATA_2019[DATA_2019["code"] == "000660"]

# CONCAT
SKHYNIX = pd.concat([data_2017,data_2018,data_2019])
SKHYNIX.to_csv("./data/SKHYNIX.csv", header=True)

# %%
Kyungdong = pd.read_csv("./data/SKHYNIX.csv")
Kyungdong = Kyungdong[Kyungdong.columns[2:-1]]

# %% [markdown]
# # **Date**

# %%
Kyungdong["date"] = pd.to_datetime(Kyungdong["date"])
Kyungdong = Kyungdong.set_index("date")

# %% [markdown]
# # **Data head**

# %%
Kyungdong.head(10)
# Out:
#              open   high    low  close  trading_volume  trading_value
# date
# 2017-01-02  44750  46000  44600  45800         1547681    70741238750
# 2017-01-03  46200  47300  46200  47250         2655477   124284065200
# 2017-01-04  47000  47150  46200  46500         2722599   127044173970
# 2017-01-05  47000  47500  46850  46950         2377163   112240246450
# 2017-01-06  47700  48450  47600  48000         3166843   152264047270
# 2017-01-09  48500  49750  48200  49550         3871999   191236382800
# 2017-01-10  49850  50200  49200  49750         2561968   127213145450
# 2017-01-11  50000  51900  50000  51600         4360058   223583642680
# 2017-01-12  51600  51600  50400  50600         5060622   256710131000
# 2017-01-13  49850  50700  49850  50300         4219771   211612764000

# %% [markdown]
# #  **Train Test Split**

# %%
Kyungdong = pd.read_csv("./data/SKHYNIX.csv")
Kyungdong = Kyungdong[Kyungdong.columns[2:-1]]

# %%
Kyungdong["date"] = pd.to_datetime(Kyungdong["date"])
Kyungdong = Kyungdong.set_index("date")

# %%
split_date = pd.Timestamp("2019-09-30")
train = Kyungdong.loc[:split_date, ["open", "high", "low", "close"]]
test = Kyungdong.loc[split_date:, ["open", "high", "low", "close"]]

# %%
ax = train.plot(figsize=(16,8), color='b', linewidth=3)
test.plot(ax=ax, color='orange', linewidth=3)
plt.legend(['train', 'test'])
plt.show()

# %% [markdown]
# # **Data MinMaxSacling**

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
train_sc = sc.fit_transform(train)
test_sc = sc.transform(test)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %% [markdown]
# # **Transform to Pandas DataFrame**

# %%
train_sc_df = pd.DataFrame(train_sc, columns=["open", "high", "low", "close"], index=train.index)
test_sc_df = pd.DataFrame(test_sc, columns=["open", "high", "low", "close"], index=test.index)

# %% [markdown]
# # **train_sc_df**

# %%
train_sc_df
# Out:
#                 open      high    low     close
# date
# 2017-01-02  0.000000  0.000000  0.000  0.000000
# 2017-01-03  0.028684  0.025145  0.032  0.029293
# 2017-01-04  0.044510  0.022244  0.032  0.014141
# 2017-01-05  0.044510  0.029014  0.045  0.023232
# 2017-01-06  0.058358  0.047389  0.060  0.044444
# ...              ...       ...    ...       ...
# 2019-09-24  0.746785  0.725338  0.736  0.759596
# 2019-09-25  0.740851  0.711799  0.738  0.729293
# 2019-09-26  0.756677  0.725338  0.758  0.757576
# 2019-09-27  0.701286  0.686654  0.710  0.719192
# 2019-09-30  0.709199  0.713733  0.716  0.735354
#
# [671 rows x 4 columns]

# %% [markdown]
# # **Setting for Sliding Window**

# %%
# List
columns = ["open", "high", "low", "close"]

for col in columns : 
    for s in range(1, 13):
        train_sc_df['{} shift_-{}'.format(col,s)] = train_sc_df[col].shift(s)
        test_sc_df['{} shift_-{}'.format(col,s)] = test_sc_df[col].shift(s)
train_sc_df.head(13)
# Out:
#                 open      high    low     close  open shift_-1  open shift_-2  \
# date
# 2017-01-02  0.000000  0.000000  0.000  0.000000            NaN            NaN
# 2017-01-03  0.028684  0.025145  0.032  0.029293       0.000000            NaN
# 2017-01-04  0.044510  0.022244  0.032  0.014141       0.028684       0.000000
# 2017-01-05  0.044510  0.029014  0.045  0.023232       0.044510       0.028684
# 2017-01-06  0.058358  0.047389  0.060  0.044444       0.044510       0.044510
# 2017-01-09  0.074184  0.072534  0.072  0.075758       0.058358       0.044510
# 2017-01-10  0.100890  0.081238  0.092  0.079798       0.074184       0.058358
# 2017-01-11  0.103858  0.114120  0.108  0.117172       0.100890       0.074184
# 2017-01-12  0.135509  0.108317  0.116  0.096970       0.103858       0.100890
# 2017-01-13  0.100890  0.090909  0.105  0.090909       0.135509       0.103858
# 2017-01-16  0.105836  0.083172  0.084  0.070707       0.100890       0.135509
# 2017-01-17  0.090010  0.081238  0.093  0.070707       0.105836       0.100890
# 2017-01-18  0.083086  0.065764  0.074  0.061616       0.090010       0.105836
#
#             open shift_-3  open shift_-4  open shift_-5  open shift_-6  ...  \
# date                                                                    ...
# 2017-01-02            NaN            NaN            NaN            NaN  ...
# 2017-01-03            NaN            NaN            NaN            NaN  ...
# 2017-01-04            NaN            NaN            NaN            NaN  ...
# 2017-01-05       0.000000            NaN            NaN            NaN  ...
# 2017-01-06       0.028684       0.000000            NaN            NaN  ...
# 2017-01-09       0.044510       0.028684       0.000000            NaN  ...
# 2017-01-10       0.044510       0.044510       0.028684       0.000000  ...
# 2017-01-11       0.058358       0.044510       0.044510       0.028684  ...
# 2017-01-12       0.074184       0.058358       0.044510       0.044510  ...
# 2017-01-13       0.100890       0.074184       0.058358       0.044510  ...
# 2017-01-16       0.103858       0.100890       0.074184       0.058358  ...
# 2017-01-17       0.135509       0.103858       0.100890       0.074184  ...
# 2017-01-18       0.100890       0.135509       0.103858       0.100890  ...
#
#             close shift_-3  close shift_-4  close shift_-5  close shift_-6  \
# date
# 2017-01-02             NaN             NaN             NaN             NaN
# 2017-01-03             NaN             NaN             NaN             NaN
# 2017-01-04             NaN             NaN             NaN             NaN
# 2017-01-05        0.000000             NaN             NaN             NaN
# 2017-01-06        0.029293        0.000000             NaN             NaN
# 2017-01-09        0.014141        0.029293        0.000000             NaN
# 2017-01-10        0.023232        0.014141        0.029293        0.000000
# 2017-01-11        0.044444        0.023232        0.014141        0.029293
# 2017-01-12        0.075758        0.044444        0.023232        0.014141
# 2017-01-13        0.079798        0.075758        0.044444        0.023232
# 2017-01-16        0.117172        0.079798        0.075758        0.044444
# 2017-01-17        0.096970        0.117172        0.079798        0.075758
# 2017-01-18        0.090909        0.096970        0.117172        0.079798
#
#             close shift_-7  close shift_-8  close shift_-9  close shift_-10  \
# date
# 2017-01-02             NaN             NaN             NaN              NaN
# 2017-01-03             NaN             NaN             NaN              NaN
# 2017-01-04             NaN             NaN             NaN              NaN
# 2017-01-05             NaN             NaN             NaN              NaN
# 2017-01-06             NaN             NaN             NaN              NaN
# 2017-01-09             NaN             NaN             NaN              NaN
# 2017-01-10             NaN             NaN             NaN              NaN
# 2017-01-11        0.000000             NaN             NaN              NaN
# 2017-01-12        0.029293        0.000000             NaN              NaN
# 2017-01-13        0.014141        0.029293        0.000000              NaN
# 2017-01-16        0.023232        0.014141        0.029293         0.000000
# 2017-01-17        0.044444        0.023232        0.014141         0.029293
# 2017-01-18        0.075758        0.044444        0.023232         0.014141
#
#             close shift_-11  close shift_-12
# date
# 2017-01-02              NaN              NaN
# 2017-01-03              NaN              NaN
# 2017-01-04              NaN              NaN
# 2017-01-05              NaN              NaN
# 2017-01-06              NaN              NaN
# 2017-01-09              NaN              NaN
# 2017-01-10              NaN              NaN
# 2017-01-11              NaN              NaN
# 2017-01-12              NaN              NaN
# 2017-01-13              NaN              NaN
# 2017-01-16              NaN              NaN
# 2017-01-17         0.000000              NaN
# 2017-01-18         0.029293              0.0
#
# [13 rows x 52 columns]

# %% [markdown]
# # **NaN Omit**

# %%
X_train = train_sc_df.dropna().drop(["open", "high", "low", "close"], axis=1)
y_train = train_sc_df.dropna()[["open", "high", "low", "close"]]["close"]

# %%
X_test = test_sc_df.dropna().drop(["open", "high", "low", "close"], axis=1)
y_test = test_sc_df.dropna()[["open", "high", "low", "close"]]["close"]

# %% [markdown]
# # **Final Train & Test**

# %%
X_train.head()
# Out:
#             open shift_-1  open shift_-2  open shift_-3  open shift_-4  \
# date
# 2017-01-18       0.090010       0.105836       0.100890       0.135509
# 2017-01-19       0.083086       0.090010       0.105836       0.100890
# 2017-01-20       0.094955       0.083086       0.090010       0.105836
# 2017-01-23       0.097923       0.094955       0.083086       0.090010
# 2017-01-24       0.102868       0.097923       0.094955       0.083086
#
#             open shift_-5  open shift_-6  open shift_-7  open shift_-8  \
# date
# 2017-01-18       0.103858       0.100890       0.074184       0.058358
# 2017-01-19       0.135509       0.103858       0.100890       0.074184
# 2017-01-20       0.100890       0.135509       0.103858       0.100890
# 2017-01-23       0.105836       0.100890       0.135509       0.103858
# 2017-01-24       0.090010       0.105836       0.100890       0.135509
#
#             open shift_-9  open shift_-10  ...  close shift_-3  \
# date                                       ...
# 2017-01-18       0.044510        0.044510  ...        0.090909
# 2017-01-19       0.058358        0.044510  ...        0.070707
# 2017-01-20       0.074184        0.058358  ...        0.070707
# 2017-01-23       0.100890        0.074184  ...        0.061616
# 2017-01-24       0.103858        0.100890  ...        0.076768
#
#             close shift_-4  close shift_-5  close shift_-6  close shift_-7  \
# date
# 2017-01-18        0.096970        0.117172        0.079798        0.075758
# 2017-01-19        0.090909        0.096970        0.117172        0.079798
# 2017-01-20        0.070707        0.090909        0.096970        0.117172
# 2017-01-23        0.070707        0.070707        0.090909        0.096970
# 2017-01-24        0.061616        0.070707        0.070707        0.090909
#
#             close shift_-8  close shift_-9  close shift_-10  close shift_-11  \
# date
# 2017-01-18        0.044444        0.023232         0.014141         0.029293
# 2017-01-19        0.075758        0.044444         0.023232         0.014141
# 2017-01-20        0.079798        0.075758         0.044444         0.023232
# 2017-01-23        0.117172        0.079798         0.075758         0.044444
# 2017-01-24        0.096970        0.117172         0.079798         0.075758
#
#             close shift_-12
# date
# 2017-01-18         0.000000
# 2017-01-19         0.029293
# 2017-01-20         0.014141
# 2017-01-23         0.023232
# 2017-01-24         0.044444
#
# [5 rows x 48 columns]

# %%
y_train.head()
# Out:
# date
# 2017-01-18    0.061616
# 2017-01-19    0.076768
# 2017-01-20    0.067677
# 2017-01-23    0.101010
# 2017-01-24    0.117172
# Name: close, dtype: float64

# %%
X_test.head()
# Out:
#             open shift_-1  open shift_-2  open shift_-3  open shift_-4  \
# date
# 2019-10-18       0.736894       0.744807       0.711177       0.736894
# 2019-10-21       0.727003       0.736894       0.744807       0.711177
# 2019-10-22       0.653808       0.727003       0.736894       0.744807
# 2019-10-23       0.675569       0.653808       0.727003       0.736894
# 2019-10-24       0.667656       0.675569       0.653808       0.727003
#
#             open shift_-5  open shift_-6  open shift_-7  open shift_-8  \
# date
# 2019-10-18       0.693373       0.675569       0.705242       0.711177
# 2019-10-21       0.736894       0.693373       0.675569       0.705242
# 2019-10-22       0.711177       0.736894       0.693373       0.675569
# 2019-10-23       0.744807       0.711177       0.736894       0.693373
# 2019-10-24       0.736894       0.744807       0.711177       0.736894
#
#             open shift_-9  open shift_-10  ...  close shift_-3  \
# date                                       ...
# 2019-10-18       0.675569        0.728981  ...        0.715152
# 2019-10-21       0.711177        0.675569  ...        0.739394
# 2019-10-22       0.705242        0.711177  ...        0.711111
# 2019-10-23       0.675569        0.705242  ...        0.638384
# 2019-10-24       0.693373        0.675569  ...        0.640404
#
#             close shift_-4  close shift_-5  close shift_-6  close shift_-7  \
# date
# 2019-10-18        0.701010        0.690909        0.670707        0.709091
# 2019-10-21        0.715152        0.701010        0.690909        0.670707
# 2019-10-22        0.739394        0.715152        0.701010        0.690909
# 2019-10-23        0.711111        0.739394        0.715152        0.701010
# 2019-10-24        0.638384        0.711111        0.739394        0.715152
#
#             close shift_-8  close shift_-9  close shift_-10  close shift_-11  \
# date
# 2019-10-18        0.696970        0.696970         0.680808         0.731313
# 2019-10-21        0.709091        0.696970         0.696970         0.680808
# 2019-10-22        0.670707        0.709091         0.696970         0.696970
# 2019-10-23        0.690909        0.670707         0.709091         0.696970
# 2019-10-24        0.701010        0.690909         0.670707         0.709091
#
#             close shift_-12
# date
# 2019-10-18         0.735354
# 2019-10-21         0.731313
# 2019-10-22         0.680808
# 2019-10-23         0.696970
# 2019-10-24         0.696970
#
# [5 rows x 48 columns]

# %%
y_test.head()
# Out:
# date
# 2019-10-18    0.638384
# 2019-10-21    0.640404
# 2019-10-22    0.672727
# 2019-10-23    0.644444
# 2019-10-24    0.690909
# Name: close, dtype: float64

# %% [markdown]
# # **ndarray to Tranform**

# %%
X_train = X_train.values
X_test = X_test.values
y_train = y_train.values
y_test = y_test.values

# %% [markdown]
# # **Final Training Set & Test Set's X**

# %%
X_train_t = X_train.reshape(X_train.shape[0], 48, 1)
X_test_t = X_test.reshape(X_test.shape[0], 48, 1)

# %% [markdown]
# # **LSTM Model**

# %%
from keras.layers import LSTM 
from keras.models import Sequential 
from keras.layers import Dense 
import keras.backend as K
from keras.callbacks import EarlyStopping
from keras.layers import Dense, Dropout, Activation
K.clear_session() 
model = Sequential() # Sequeatial Model 
model.add(LSTM(20, input_shape=(48,1))) # (timestep, feature) 
model.add(Dense(1)) # output = 1 
model.compile(loss='mean_squared_error', optimizer='adam') 
model.summary()
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 20)                1760
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 1,781
# Trainable params: 1,781
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # **Model Fitting**

# %%
early_stop = EarlyStopping(monitor='loss', patience=10, verbose=1)
model.fit(X_train_t, y_train, epochs=150, batch_size=100, verbose=1, callbacks=[early_stop])
# Out:
# Epoch 1/150
# 659/659 [==============================] - 2s 3ms/step - loss: 0.2600
# Epoch 2/150
# 659/659 [==============================] - 0s 725us/step - loss: 0.1620
# Epoch 3/150
# 659/659 [==============================] - 0s 681us/step - loss: 0.0786
# Epoch 4/150
# 659/659 [==============================] - 0s 667us/step - loss: 0.0229
# Epoch 5/150
# 659/659 [==============================] - 0s 667us/step - loss: 0.0155
# Epoch 6/150
# 659/659 [==============================] - 0s 645us/step - loss: 0.0162
# Epoch 7/150
# 659/659 [==============================] - 0s 675us/step - loss: 0.0109
# Epoch 8/150
# 659/659 [==============================] - 0s 660us/step - loss: 0.0113
# Epoch 9/150
# 659/659 [==============================] - 0s 673us/step - loss: 0.0103
# Epoch 10/150
# 659/659 [==============================] - 0s 663us/step - loss: 0.0096
# Epoch 11/150
# 659/659 [==============================] - 0s 670us/step - loss: 0.0093
# Epoch 12/150
# 659/659 [==============================] - 0s 658us/step - loss: 0.0088
# Epoch 13/150
# 659/659 [==============================] - 0s 637us/step - loss: 0.0084
# Epoch 14/150
# 659/659 [==============================] - 0s 615us/step - loss: 0.0081
# Epoch 15/150
# 659/659 [==============================] - 0s 635us/step - loss: 0.0078
# Epoch 16/150
# 659/659 [==============================] - 0s 648us/step - loss: 0.0075 0s - loss: 0
# Epoch 17/150
# 659/659 [==============================] - 0s 593us/step - loss: 0.0072
# Epoch 18/150
# 659/659 [==============================] - 0s 613us/step - loss: 0.0070
# Epoch 19/150
# 659/659 [==============================] - 0s 611us/step - loss: 0.0069
# Epoch 20/150
# 659/659 [==============================] - 0s 619us/step - loss: 0.0067
# Epoch 21/150
# 659/659 [==============================] - 0s 587us/step - loss: 0.0065
# Epoch 22/150
# 659/659 [==============================] - 0s 607us/step - loss: 0.0065
# Epoch 23/150
# 659/659 [==============================] - 0s 610us/step - loss: 0.0064
# Epoch 24/150
# 659/659 [==============================] - 0s 617us/step - loss: 0.0063
# Epoch 25/150
# 659/659 [==============================] - 0s 620us/step - loss: 0.0063
# Epoch 26/150
# 659/659 [==============================] - 0s 617us/step - loss: 0.0062
# Epoch 27/150
# 659/659 [==============================] - 0s 568us/step - loss: 0.0062
# Epoch 28/150
# 659/659 [==============================] - 0s 614us/step - loss: 0.0061 0s - loss: 0.006
# Epoch 29/150
# 659/659 [==============================] - 0s 624us/step - loss: 0.0061
# Epoch 30/150
# 659/659 [==============================] - 0s 607us/step - loss: 0.0061
# Epoch 31/150
# 659/659 [==============================] - 0s 620us/step - loss: 0.0061
# Epoch 32/150
# 659/659 [==============================] - 0s 584us/step - loss: 0.0060
# Epoch 33/150
# 659/659 [==============================] - 0s 624us/step - loss: 0.0060
# Epoch 34/150
# 659/659 [==============================] - 0s 618us/step - loss: 0.0060
# Epoch 35/150
# 659/659 [==============================] - 0s 616us/step - loss: 0.0060
# Epoch 36/150
# 659/659 [==============================] - 0s 590us/step - loss: 0.0060
# Epoch 37/150
# 659/659 [==============================] - 0s 561us/step - loss: 0.0060
# Epoch 38/150
# 659/659 [==============================] - 0s 569us/step - loss: 0.0060
# Epoch 39/150
# 659/659 [==============================] - 0s 617us/step - loss: 0.0059
# Epoch 40/150
# 659/659 [==============================] - 0s 611us/step - loss: 0.0060
# Epoch 41/150
# 659/659 [==============================] - 0s 617us/step - loss: 0.0060
# Epoch 42/150
# 659/659 [==============================] - 0s 587us/step - loss: 0.0059
# Epoch 43/150
# 659/659 [==============================] - 0s 614us/step - loss: 0.0058
# Epoch 44/150
# 659/659 [==============================] - 0s 617us/step - loss: 0.0059
# Epoch 45/150
# 659/659 [==============================] - 0s 605us/step - loss: 0.0058
# Epoch 46/150
# 659/659 [==============================] - 0s 614us/step - loss: 0.0058
# Epoch 47/150
# 659/659 [==============================] - 0s 574us/step - loss: 0.0059
# Epoch 48/150
# 659/659 [==============================] - 0s 616us/step - loss: 0.0057
# Epoch 49/150
# 659/659 [==============================] - 0s 619us/step - loss: 0.0057
# Epoch 50/150
# 659/659 [==============================] - 0s 616us/step - loss: 0.0057 0s - loss: 0.
# Epoch 51/150
# 659/659 [==============================] - 0s 575us/step - loss: 0.0057
# Epoch 52/150
# 659/659 [==============================] - 0s 512us/step - loss: 0.0056
# Epoch 53/150
# 659/659 [==============================] - 0s 577us/step - loss: 0.0056
# Epoch 54/150
# 659/659 [==============================] - 0s 611us/step - loss: 0.0056
# Epoch 55/150
# 659/659 [==============================] - 0s 617us/step - loss: 0.0056
# Epoch 56/150
# 659/659 [==============================] - 0s 624us/step - loss: 0.0055
# Epoch 57/150
# 659/659 [==============================] - 0s 599us/step - loss: 0.0056
# Epoch 58/150
# 659/659 [==============================] - 0s 613us/step - loss: 0.0055
# Epoch 59/150
# 659/659 [==============================] - ETA: 0s - loss: 0.005 - 0s 614us/step - loss: 0.0057
# Epoch 60/150
# 659/659 [==============================] - 0s 617us/step - loss: 0.0057
# Epoch 61/150
# 659/659 [==============================] - 0s 603us/step - loss: 0.0057
# Epoch 62/150
# 659/659 [==============================] - 0s 596us/step - loss: 0.0055
# Epoch 63/150
# 659/659 [==============================] - 0s 617us/step - loss: 0.0054
# Epoch 64/150
# 659/659 [==============================] - 0s 611us/step - loss: 0.0055
# Epoch 65/150
# 659/659 [==============================] - 0s 549us/step - loss: 0.0054
# Epoch 66/150
# 659/659 [==============================] - 0s 549us/step - loss: 0.0054
# Epoch 67/150
# 659/659 [==============================] - 0s 504us/step - loss: 0.0054
# Epoch 68/150
# 659/659 [==============================] - 0s 537us/step - loss: 0.0053
# Epoch 69/150
# 659/659 [==============================] - 0s 543us/step - loss: 0.0053
# Epoch 70/150
# 659/659 [==============================] - 0s 545us/step - loss: 0.0053
# Epoch 71/150
# 659/659 [==============================] - 0s 554us/step - loss: 0.0052
# Epoch 72/150
# 659/659 [==============================] - 0s 502us/step - loss: 0.0053
# Epoch 73/150
# 659/659 [==============================] - 0s 536us/step - loss: 0.0053
# Epoch 74/150
# 659/659 [==============================] - 0s 537us/step - loss: 0.0053
# Epoch 75/150
# 659/659 [==============================] - 0s 546us/step - loss: 0.0053
# Epoch 76/150
# 659/659 [==============================] - 0s 557us/step - loss: 0.0053
# Epoch 77/150
# 659/659 [==============================] - 0s 539us/step - loss: 0.0052
# Epoch 78/150
# 659/659 [==============================] - 0s 501us/step - loss: 0.0052
# Epoch 79/150
# 659/659 [==============================] - 0s 522us/step - loss: 0.0051
# Epoch 80/150
# 659/659 [==============================] - 0s 527us/step - loss: 0.0051
# Epoch 81/150
# 659/659 [==============================] - 0s 532us/step - loss: 0.0052
# Epoch 82/150
# 659/659 [==============================] - 0s 542us/step - loss: 0.0052
# Epoch 83/150
# 659/659 [==============================] - 0s 552us/step - loss: 0.0050
# Epoch 84/150
# 659/659 [==============================] - 0s 499us/step - loss: 0.0051
# Epoch 85/150
# 659/659 [==============================] - 0s 525us/step - loss: 0.0050
# Epoch 86/150
# 659/659 [==============================] - 0s 545us/step - loss: 0.0051
# Epoch 87/150
# 659/659 [==============================] - 0s 527us/step - loss: 0.0050
# Epoch 88/150
# 659/659 [==============================] - 0s 534us/step - loss: 0.0050
# Epoch 89/150
# 659/659 [==============================] - 0s 513us/step - loss: 0.0050
# Epoch 90/150
# 659/659 [==============================] - 0s 528us/step - loss: 0.0050
# Epoch 91/150
# 659/659 [==============================] - 0s 568us/step - loss: 0.0049
# Epoch 92/150
# 659/659 [==============================] - 0s 574us/step - loss: 0.0050
# Epoch 93/150
# 659/659 [==============================] - 0s 589us/step - loss: 0.0049
# Epoch 94/150
# 659/659 [==============================] - 0s 611us/step - loss: 0.0049
# Epoch 95/150
# 659/659 [==============================] - 0s 589us/step - loss: 0.0049
# Epoch 96/150
# 659/659 [==============================] - 0s 595us/step - loss: 0.0049
# Epoch 97/150
# 659/659 [==============================] - 0s 610us/step - loss: 0.0048
# Epoch 98/150
# 659/659 [==============================] - 0s 611us/step - loss: 0.0049
# Epoch 99/150
# 659/659 [==============================] - 0s 616us/step - loss: 0.0048 0s - loss: 0.00
# Epoch 100/150
# 659/659 [==============================] - 0s 583us/step - loss: 0.0048
# Epoch 101/150
# 659/659 [==============================] - 0s 620us/step - loss: 0.0048
# Epoch 102/150
# 659/659 [==============================] - 0s 631us/step - loss: 0.0047
# Epoch 103/150
# 659/659 [==============================] - 0s 642us/step - loss: 0.0049
# Epoch 104/150
# 659/659 [==============================] - 0s 622us/step - loss: 0.0048
# Epoch 105/150
# 659/659 [==============================] - 0s 586us/step - loss: 0.0048
# Epoch 106/150
# 659/659 [==============================] - 0s 617us/step - loss: 0.0047
# Epoch 107/150
# 659/659 [==============================] - 0s 613us/step - loss: 0.0047
# Epoch 108/150
# 659/659 [==============================] - 0s 614us/step - loss: 0.0047
# Epoch 109/150
# 659/659 [==============================] - 0s 625us/step - loss: 0.0047
# Epoch 110/150
# 659/659 [==============================] - 0s 593us/step - loss: 0.0047
# Epoch 111/150
# 659/659 [==============================] - 0s 622us/step - loss: 0.0046
# Epoch 112/150
# 659/659 [==============================] - 0s 616us/step - loss: 0.0046
# Epoch 113/150
# 659/659 [==============================] - 0s 616us/step - loss: 0.0048
# Epoch 114/150
# 659/659 [==============================] - 0s 602us/step - loss: 0.0047
# Epoch 115/150
# 659/659 [==============================] - 0s 602us/step - loss: 0.0046
# Epoch 116/150
# 659/659 [==============================] - 0s 592us/step - loss: 0.0047
# Epoch 117/150
# 659/659 [==============================] - 0s 587us/step - loss: 0.0045
# Epoch 118/150
# 659/659 [==============================] - 0s 617us/step - loss: 0.0045
# Epoch 119/150
# 659/659 [==============================] - 0s 589us/step - loss: 0.0045
# Epoch 120/150
# 659/659 [==============================] - 0s 598us/step - loss: 0.0045
# Epoch 121/150
# 659/659 [==============================] - 0s 610us/step - loss: 0.0044
# Epoch 122/150
# 659/659 [==============================] - 0s 607us/step - loss: 0.0044
# Epoch 123/150
# 659/659 [==============================] - 0s 619us/step - loss: 0.0044
# Epoch 124/150
# 659/659 [==============================] - 0s 593us/step - loss: 0.0044
# Epoch 125/150
# 659/659 [==============================] - 0s 563us/step - loss: 0.0043
# Epoch 126/150
# 659/659 [==============================] - 0s 621us/step - loss: 0.0043
# Epoch 127/150
# 659/659 [==============================] - 0s 614us/step - loss: 0.0043
# Epoch 128/150
# 659/659 [==============================] - 0s 622us/step - loss: 0.0044
# Epoch 129/150
# 659/659 [==============================] - 0s 602us/step - loss: 0.0042
# Epoch 130/150
# 659/659 [==============================] - 0s 551us/step - loss: 0.0042
# Epoch 131/150
# 659/659 [==============================] - 0s 627us/step - loss: 0.0043
# Epoch 132/150
# 659/659 [==============================] - 0s 607us/step - loss: 0.0042
# Epoch 133/150
# 659/659 [==============================] - 0s 622us/step - loss: 0.0042
# Epoch 134/150
# 659/659 [==============================] - 0s 605us/step - loss: 0.0043
# Epoch 135/150
# 659/659 [==============================] - 0s 571us/step - loss: 0.0041
# Epoch 136/150
# 659/659 [==============================] - 0s 619us/step - loss: 0.0041
# Epoch 137/150
# 659/659 [==============================] - 0s 617us/step - loss: 0.0042
# Epoch 138/150
# 659/659 [==============================] - 0s 624us/step - loss: 0.0040
# Epoch 139/150
# 659/659 [==============================] - 0s 615us/step - loss: 0.0040
# Epoch 140/150
# 659/659 [==============================] - 0s 578us/step - loss: 0.0040
# Epoch 141/150
# 659/659 [==============================] - 0s 619us/step - loss: 0.0039
# Epoch 142/150
# 659/659 [==============================] - 0s 611us/step - loss: 0.0039
# Epoch 143/150
# 659/659 [==============================] - 0s 622us/step - loss: 0.0038
# Epoch 144/150
# 659/659 [==============================] - 0s 592us/step - loss: 0.0039
# Epoch 145/150
# 659/659 [==============================] - 0s 575us/step - loss: 0.0041
# Epoch 146/150
# 659/659 [==============================] - 0s 613us/step - loss: 0.0041
# Epoch 147/150
# 659/659 [==============================] - 0s 613us/step - loss: 0.0040
# Epoch 148/150
# 659/659 [==============================] - 0s 619us/step - loss: 0.0040
# Epoch 149/150
# 659/659 [==============================] - 0s 602us/step - loss: 0.0039
# Epoch 150/150
# 659/659 [==============================] - 0s 619us/step - loss: 0.0038

# %% [markdown]
# # **Train Prediction**

# %%
# Pred
y_pred = model.predict(X_train_t)
PRED = pd.DataFrame(y_pred)
PRED.columns = ["PRED"]

# %%
# Actual
REAL = pd.DataFrame(y_train)
REAL.columns = ["REAL"]

# %%
# Setting
RESULT = pd.concat([REAL,PRED], axis=1)
RESULT["date"] = train.index[12:]

# %%
# Set Index
RESULT = RESULT.set_index("date")

# %%
y_pred = model.predict(X_train_t)
y_pred = y_pred * (np.max(train["close"]) -  np.min(train["close"])) +  np.min(train["close"])
y_pred_df = pd.DataFrame(y_pred, columns=['prediction'], index=train.index[:-12])

# %%
y_train = y_train * (np.max(train["close"]) -  np.min(train["close"])) +  np.min(train["close"])
y_train_df = pd.DataFrame(y_train, columns=['actual_price'], index=train.index[:-12])

# %%
# plotting the results
fig = plt.figure(figsize=(16,8))
fig.patch.set_facecolor('xkcd:white')
plt.plot(y_pred_df["prediction"], color = 'blue', label = 'Predicted Stock Price', linewidth = 3)
plt.plot(y_train_df["actual_price"], color = 'red', label = 'Actual Stock Price', linewidth = 3)
plt.title('Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# # **Test Prediction**

# %%
# Pred
y_pred = model.predict(X_test_t)
PRED = pd.DataFrame(y_pred)
PRED.columns = ["PRED"]

# %%
# Actual
REAL = pd.DataFrame(y_test)
REAL.columns = ["REAL"]

# %%
RESULT_TEST = pd.concat([REAL,PRED], axis=1)
RESULT_TEST["date"] = test.index[12:]

# %%
RESULT_TEST = RESULT_TEST.set_index("date")

# %% [markdown]
# # **Test Visualization**

# %%
y_pred = model.predict(X_test_t)
y_pred = y_pred * (np.max(test["close"]) -  np.min(test["close"])) +  np.min(test["close"])
y_pred_df = pd.DataFrame(y_pred, columns=['prediction'], index=test.index[12:])

# %%
y_test = y_test * (np.max(test["close"]) -  np.min(test["close"])) +  np.min(test["close"])
y_test_df = pd.DataFrame(y_test, columns=['actual_price'], index=test.index[12:])

# %%
# plotting the results
fig = plt.figure(figsize=(16,8))
fig.patch.set_facecolor('xkcd:white')
plt.plot(y_pred_df["prediction"], color = 'blue', label = 'Predicted Stock Price', linewidth = 3)
plt.plot(y_test_df["actual_price"], color = 'red', label = 'Actual Stock Price', linewidth = 3)
plt.title('Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# # **RMSE**

# %%
forecast_error = y_test.reshape(-1,1) - y_pred
SS, RMSE = 0, 0
for i in forecast_error : 
    SS = SS + i * i
    RMSE = SS / len(forecast_error)
print("Test DataSet's RMSE : {}" .format(float(RMSE**0.5)))
# Out:
# Test DataSet's RMSE : 1574.6127290959262
